# %%
from pathlib import Path

# === PARAMÈTRES ===
root = Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/limatch_F2B_v1")
output_file = Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/limatch_F2B_v1/LiDAR_p2p_test.txt")

# === RECHERCHE DES DOSSIERS cor_outputs ===
cor_dirs = sorted(p for p in root.rglob("cor_outputs") if p.is_dir())

# === RECHERCHE DES FICHIERS À MERGER ===
files_to_merge = []
for d in cor_dirs:
    files_to_merge.extend(sorted(d.glob("LiDAR_p2p_chunk*")))

files_to_merge = [f for f in files_to_merge if f.is_file()]

print(f"{len(files_to_merge)} fichiers trouvés.")

# === MERGE ===
output_file.parent.mkdir(parents=True, exist_ok=True)

with output_file.open("w", encoding="utf-8") as fout:
    for f in files_to_merge:
        with f.open("r", encoding="utf-8", errors="replace") as fin:
            content = fin.read()
            fout.write(content)
            if not content.endswith("\n"):
                fout.write("\n")

print(f"Merge terminé : {output_file}")
# Out:
# 80 fichiers trouvés.
# Merge terminé : /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/limatch_F2B_v1/LiDAR_p2p_test.txt

# %%
import numpy as np

f1 = "/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/COMBINED/in/LiDAR_p2p.txt"
f2 = "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/limatch_debug/9000_10000/cor_outputs/LiDAR_p2p.txt"
out = "/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/COMBINED/in/LiDAR_p2p.txt"


a = np.loadtxt(f1, delimiter=",")
b = np.loadtxt(f2, delimiter=",")

print(f"File 1: {len(a)} lines")
print(f"File 2: {len(b)} lines")

merged = np.vstack([a, b])
merged = merged[np.argsort(merged[:, 0])]

print(f"Merged: {len(merged)} lines")

np.savetxt(out, merged, fmt="%.10f", delimiter=",")
# Out:
# File 1: 68333 lines
# File 2: 1728 lines
# Merged: 70061 lines

# %%
from pathlib import Path
import subprocess
import shutil

# ============================================================
# INPUT
# ============================================================
root = Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/")

# ============================================================
# FIND FILES
# seulement LiDAR_p2p_*.txt
# exclut LiDAR_p2p_rsc_*.txt
# ============================================================
files = sorted(
    f for f in root.rglob("LiDAR_p2p_*.txt")
    if not f.name.startswith("LiDAR_p2p_rsc_")
)

out_raw    = root / "LiDAR_p2p_merged_raw.txt"
out_clean  = root / "LiDAR_p2p_merged_clean.txt"
out_sorted = root / "LiDAR_p2p_merged_sorted.txt"

if not files:
    raise FileNotFoundError(f"Aucun fichier LiDAR_p2p_*.txt trouvé dans {root}")

print(f"{len(files)} fichier(s) trouvé(s)")
for f in files[:20]:
    print(" -", f)
if len(files) > 20:
    print(f" ... + {len(files)-20} autres")

# ============================================================
# MERGE
# ============================================================
with open(out_raw, "w") as fout:
    for f in files:
        with open(f, "r") as fin:
            for line in fin:
                if line.strip():
                    fout.write(line)

print(f"\nMerge brut écrit dans : {out_raw}")

# ============================================================
# CLEAN
# garde seulement les lignes dont la première colonne est numérique
# ============================================================
n_in, n_out, n_bad = 0, 0, 0

with open(out_raw, "r") as fin, open(out_clean, "w") as fout:
    for line in fin:
        n_in += 1
        s = line.strip()
        if not s:
            continue

        parts = s.replace(",", " ").split()
        if not parts:
            n_bad += 1
            continue

        try:
            float(parts[0])
            fout.write(line)
            n_out += 1
        except ValueError:
            n_bad += 1

print("\nNettoyage terminé")
print("  lignes lues    :", n_in)
print("  lignes gardées :", n_out)
print("  lignes rejetées:", n_bad)
print("Fichier clean :", out_clean)

# ============================================================
# SORT sur la première colonne
# ============================================================
if shutil.which("sort") is None:
    raise RuntimeError("La commande 'sort' n'est pas disponible sur ce système.")

cmd = f"sort -g -k1,1 '{out_clean}' > '{out_sorted}'"
subprocess.run(cmd, shell=True, check=True)

print(f"\nFichier final trié écrit dans : {out_sorted}")
# Out:
# 161 fichier(s) trouvé(s)
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_13000/Patch_from_scan_10000_with_13000_vs_Patch_from_scan_13000_with_10000/limatch/chunk_0001/cor_outputs/LiDAR_p2p_chunk_0001_chunk_0001.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_13000/Patch_from_scan_10000_with_13000_vs_Patch_from_scan_13000_with_10000/limatch/chunk_0002/cor_outputs/LiDAR_p2p_chunk_0002_chunk_0002.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_15000/Patch_from_scan_10000_with_15000_vs_Patch_from_scan_15000_with_10000/limatch/chunk_0001/cor_outputs/LiDAR_p2p_chunk_0001_chunk_0001.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_15000/Patch_from_scan_10000_with_15000_vs_Patch_from_scan_15000_with_10000/limatch/chunk_0002/cor_outputs/LiDAR_p2p_chunk_0002_chunk_0002.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_15000/Patch_from_scan_10000_with_15000_vs_Patch_from_scan_15000_with_10000/limatch/chunk_0003/cor_outputs/LiDAR_p2p_chunk_0003_chunk_0003.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_16000/Patch_from_scan_10000_with_16000_vs_Patch_from_scan_16000_with_10000/limatch/chunk_0001/cor_outputs/LiDAR_p2p_chunk_0001_chunk_0001.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_16000/Patch_from_scan_10000_with_16000_vs_Patch_from_scan_16000_with_10000/limatch/chunk_0002/cor_outputs/LiDAR_p2p_chunk_0002_chunk_0002.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_16000/Patch_from_scan_10000_with_16000_vs_Patch_from_scan_16000_with_10000/limatch/chunk_0003/cor_outputs/LiDAR_p2p_chunk_0003_chunk_0003.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_17000/Patch_from_scan_10000_with_17000_vs_Patch_from_scan_17000_with_10000/limatch/chunk_0001/cor_outputs/LiDAR_p2p_chunk_0001_chunk_0001.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_17000/Patch_from_scan_10000_with_17000_vs_Patch_from_scan_17000_with_10000/limatch/chunk_0002/cor_outputs/LiDAR_p2p_chunk_0002_chunk_0002.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_17000/Patch_from_scan_10000_with_17000_vs_Patch_from_scan_17000_with_10000/limatch/chunk_0003/cor_outputs/LiDAR_p2p_chunk_0003_chunk_0003.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_18000/Patch_from_scan_10000_with_18000_vs_Patch_from_scan_18000_with_10000/limatch/chunk_0001/cor_outputs/LiDAR_p2p_chunk_0001_chunk_0001.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_18000/Patch_from_scan_10000_with_18000_vs_Patch_from_scan_18000_with_10000/limatch/chunk_0002/cor_outputs/LiDAR_p2p_chunk_0002_chunk_0002.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_18000/Patch_from_scan_10000_with_18000_vs_Patch_from_scan_18000_with_10000/limatch/chunk_0003/cor_outputs/LiDAR_p2p_chunk_0003_chunk_0003.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_2000/Patch_from_scan_2000_with_10000_vs_Patch_from_scan_10000_with_2000/limatch/chunk_0000/cor_outputs/LiDAR_p2p_chunk_0000_chunk_0000.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_2000/Patch_from_scan_2000_with_10000_vs_Patch_from_scan_10000_with_2000/limatch/chunk_0001/cor_outputs/LiDAR_p2p_chunk_0001_chunk_0001.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_2000/Patch_from_scan_2000_with_10000_vs_Patch_from_scan_10000_with_2000/limatch/chunk_0002/cor_outputs/LiDAR_p2p_chunk_0002_chunk_0002.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_4000/Patch_from_scan_4000_with_10000_vs_Patch_from_scan_10000_with_4000/limatch/chunk_0003/cor_outputs/LiDAR_p2p_chunk_0003_chunk_0003.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_7000/Patch_from_scan_7000_with_10000_vs_Patch_from_scan_10000_with_7000/limatch/chunk_0000/cor_outputs/LiDAR_p2p_chunk_0000_chunk_0000.txt
#  - /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch/Flights_10000_7000/Patch_from_scan_7000_with_10000_vs_Patch_from_scan_10000_with_7000/limatch/chunk_0001/cor_outputs/LiDAR_p2p_chunk_0001_chunk_0001.txt
#  ... + 141 autres
#
# Merge brut écrit dans : /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/LiDAR_p2p_merged_raw.txt
#
# Nettoyage terminé
#   lignes lues    : 368259
#   lignes gardées : 368259
#   lignes rejetées: 0
# Fichier clean : /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/LiDAR_p2p_merged_clean.txt
#
# Fichier final trié écrit dans : /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/LiDAR_p2p_merged_sorted.txt

# %% [markdown]
# ### stats success rate + nombre de chunks

# %%
from pathlib import Path
import pandas as pd

BASE_PATH = "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_1/limatch"
KEYWORD   = "LiDAR_p2p"
MIN_SIZE  = 1

def find_output_file(chunk_dir, keyword, min_size):
    cor_dir = chunk_dir / "cor_outputs"
    if not cor_dir.exists():
        return False, "pas de dossier cor_outputs"
    txt_files = list(cor_dir.glob("*.txt"))
    if not txt_files:
        return False, "aucun fichier .txt"
    if keyword:
        txt_files = [f for f in txt_files if keyword in f.name]
        if not txt_files:
            return False, f"aucun fichier contenant '{keyword}'"
    for f in txt_files:
        if f.stat().st_size >= min_size:
            return True, f.name
    return False, f"fichier(s) vide(s) (< {min_size} octets)"

records = []
for sensor_dir in sorted(Path(BASE_PATH).iterdir()):
    if not sensor_dir.is_dir():
        continue
    for chunk_dir in sorted(d for d in sensor_dir.iterdir() if d.is_dir()):
        success, detail = find_output_file(chunk_dir, KEYWORD, MIN_SIZE)
        records.append({"sensor": sensor_dir.name, "chunk": chunk_dir.name,
                        "success": success, "detail": detail})

df = pd.DataFrame(records)
print(f"Chunks trouvés : {len(df)}")
# Out:
# Chunks trouvés : 436

# %%
total     = len(df)
n_success = df["success"].sum()
print(f"Total chunks   : {total}")
print(f"Réussis        : {n_success}")
print(f"Échoués        : {total - n_success}")
print(f"Success rate   : {n_success/total*100:.1f}%")
# Out:
# Total chunks   : 436
# Réussis        : 337
# Échoués        : 99
# Success rate   : 77.3%

# %%
df["status"] = df["success"].map({True: "✅", False: "❌"})
pd.set_option("display.max_rows", None)
df[["sensor", "chunk", "status", "detail"]]
# Out:
#                    sensor                   chunk status  \
# 0    merged_1000_VUX_PUCK  chunk_1000__chunk_1001      ✅
# 1    merged_1000_VUX_PUCK  chunk_1001__chunk_1002      ❌
# 2    merged_1000_VUX_PUCK  chunk_1002__chunk_1003      ❌
# 3    merged_1000_VUX_PUCK  chunk_1003__chunk_1004      ✅
# 4    merged_1000_VUX_PUCK  chunk_1004__chunk_1005      ❌
# 5    merged_1000_VUX_PUCK  chunk_1005__chunk_1006      ❌
# 6    merged_1000_VUX_PUCK  chunk_1006__chunk_1007      ❌
# 7    merged_1000_VUX_PUCK  chunk_1007__chunk_1008      ❌
# 8    merged_1000_VUX_PUCK  chunk_1008__chunk_1009      ✅
# 9    merged_1000_VUX_PUCK  chunk_1009__chunk_1010      ✅
# 10   merged_1000_VUX_PUCK  chunk_1010__chunk_1011      ✅
# 11   merged_1000_VUX_PUCK  chunk_1011__chunk_1012      ✅
# 12   merged_1000_VUX_PUCK  chunk_1012__chunk_1013      ✅
# 13   merged_1000_VUX_PUCK  chunk_1013__chunk_1014      ❌
# 14   merged_1000_VUX_PUCK  chunk_1014__chunk_1015      ❌
# 15   merged_1000_VUX_PUCK  chunk_1015__chunk_1016      ❌
# 16   merged_1000_VUX_PUCK  chunk_1016__chunk_1017      ✅
# 17   merged_1000_VUX_PUCK  chunk_1017__chunk_1018      ✅
# 18   merged_1000_VUX_PUCK  chunk_1018__chunk_1019      ❌
# 19   merged_1000_VUX_PUCK  chunk_1019__chunk_1020      ✅
# 20   merged_1000_VUX_PUCK  chunk_1020__chunk_1021      ❌
# 21   merged_1000_VUX_PUCK  chunk_1021__chunk_1022      ✅
# 22   merged_1000_VUX_PUCK  chunk_1022__chunk_1023      ✅
# 23   merged_1000_VUX_PUCK  chunk_1023__chunk_1024      ❌
# 24   merged_1000_VUX_PUCK  chunk_1024__chunk_1025      ❌
# 25   merged_1000_VUX_PUCK  chunk_1025__chunk_1026      ✅
# 26   merged_1000_VUX_PUCK  chunk_1026__chunk_1027      ✅
# 27   merged_1000_VUX_PUCK  chunk_1027__chunk_1028      ✅
# 28   merged_1000_VUX_PUCK  chunk_1028__chunk_1029      ✅
# 29   merged_1000_VUX_PUCK  chunk_1029__chunk_1030      ✅
# 30   merged_1000_VUX_PUCK  chunk_1030__chunk_1031      ✅
# 31   merged_1000_VUX_PUCK  chunk_1031__chunk_1032      ✅
# 32   merged_1000_VUX_PUCK  chunk_1032__chunk_1033      ✅
# 33   merged_1000_VUX_PUCK  chunk_1033__chunk_1034      ✅
# 34   merged_1000_VUX_PUCK  chunk_1034__chunk_1035      ✅
# 35   merged_1000_VUX_PUCK  chunk_1035__chunk_1036      ✅
# 36   merged_1000_VUX_PUCK  chunk_1036__chunk_1037      ✅
# 37   merged_1000_VUX_PUCK  chunk_1037__chunk_1038      ✅
# 38   merged_1000_VUX_PUCK  chunk_1038__chunk_1039      ✅
# 39   merged_1000_VUX_PUCK  chunk_1039__chunk_1040      ❌
# 40   merged_1000_VUX_PUCK  chunk_1040__chunk_1041      ✅
# 41   merged_1000_VUX_PUCK  chunk_1041__chunk_1042      ✅
# 42   merged_1000_VUX_PUCK  chunk_1042__chunk_1043      ✅
# 43   merged_1000_VUX_PUCK  chunk_1043__chunk_1044      ✅
# 44   merged_1000_VUX_PUCK  chunk_1044__chunk_1045      ✅
# 45   merged_1000_VUX_PUCK  chunk_1045__chunk_1046      ✅
# 46   merged_1000_VUX_PUCK  chunk_1046__chunk_1047      ✅
# 47   merged_1000_VUX_PUCK  chunk_1047__chunk_1048      ✅
# 48   merged_1000_VUX_PUCK  chunk_1048__chunk_1049      ✅
# 49   merged_1000_VUX_PUCK  chunk_1049__chunk_1050      ❌
# 50   merged_1000_VUX_PUCK  chunk_1050__chunk_1051      ✅
# 51   merged_1000_VUX_PUCK  chunk_1051__chunk_1052      ✅
# 52   merged_1000_VUX_PUCK  chunk_1052__chunk_1053      ✅
# 53   merged_1000_VUX_PUCK  chunk_1053__chunk_1054      ✅
# 54   merged_1000_VUX_PUCK  chunk_1054__chunk_1055      ✅
# 55   merged_1000_VUX_PUCK  chunk_1055__chunk_1056      ✅
# 56   merged_1000_VUX_PUCK  chunk_1056__chunk_1057      ✅
# 57   merged_1000_VUX_PUCK  chunk_1057__chunk_1058      ✅
# 58   merged_1000_VUX_PUCK  chunk_1058__chunk_1059      ✅
# 59   merged_1000_VUX_PUCK  chunk_1059__chunk_1060      ✅
# 60   merged_1000_VUX_PUCK  chunk_1060__chunk_1061      ✅
# 61   merged_1000_VUX_PUCK  chunk_1061__chunk_1062      ✅
# 62   merged_1000_VUX_PUCK  chunk_1062__chunk_1063      ✅
# 63   merged_1000_VUX_PUCK  chunk_1063__chunk_1064      ✅
# 64   merged_1000_VUX_PUCK  chunk_1064__chunk_1065      ❌
# 65   merged_1000_VUX_PUCK  chunk_1065__chunk_1066      ✅
# 66   merged_1000_VUX_PUCK  chunk_1066__chunk_1067      ✅
# 67   merged_1000_VUX_PUCK  chunk_1067__chunk_1068      ✅
# 68   merged_1000_VUX_PUCK  chunk_1068__chunk_1069      ✅
# 69   merged_1000_VUX_PUCK  chunk_1069__chunk_1070      ✅
# 70   merged_1000_VUX_PUCK  chunk_1070__chunk_1071      ✅
# 71   merged_1000_VUX_PUCK  chunk_1071__chunk_1072      ✅
# 72   merged_1000_VUX_PUCK  chunk_1072__chunk_1073      ✅
# 73   merged_1000_VUX_PUCK  chunk_1073__chunk_1074      ✅
# 74   merged_1000_VUX_PUCK  chunk_1074__chunk_1075      ✅
# 75   merged_1000_VUX_PUCK  chunk_1075__chunk_1076      ✅
# 76   merged_1000_VUX_PUCK  chunk_1076__chunk_1077      ✅
# 77   merged_1000_VUX_PUCK  chunk_1077__chunk_1078      ✅
# 78   merged_1000_VUX_PUCK  chunk_1078__chunk_1079      ✅
# 79   merged_1000_VUX_PUCK  chunk_1079__chunk_1080      ✅
# 80   merged_1000_VUX_PUCK  chunk_1080__chunk_1081      ❌
# 81   merged_1000_VUX_PUCK  chunk_1081__chunk_1082      ❌
# 82   merged_1000_VUX_PUCK  chunk_1082__chunk_1083      ✅
# 83   merged_1000_VUX_PUCK  chunk_1083__chunk_1084      ✅
# 84   merged_1000_VUX_PUCK  chunk_1084__chunk_1085      ❌
# 85   merged_1000_VUX_PUCK  chunk_1085__chunk_1086      ❌
# 86   merged_1000_VUX_PUCK  chunk_1086__chunk_1087      ❌
# 87   merged_1000_VUX_PUCK  chunk_1087__chunk_1088      ❌
# 88   merged_1000_VUX_PUCK  chunk_1088__chunk_1089      ❌
# 89   merged_1000_VUX_PUCK  chunk_1089__chunk_1090      ❌
# 90   merged_1000_VUX_PUCK  chunk_1090__chunk_1091      ❌
# 91   merged_1000_VUX_PUCK  chunk_1091__chunk_1092      ✅
# 92   merged_1000_VUX_PUCK  chunk_1092__chunk_1093      ❌
# 93   merged_1000_VUX_PUCK  chunk_1093__chunk_1094      ❌
# 94   merged_1000_VUX_PUCK  chunk_1094__chunk_1095      ❌
# 95   merged_1000_VUX_PUCK  chunk_1095__chunk_1096      ❌
# 96   merged_1000_VUX_PUCK  chunk_1096__chunk_1097      ❌
# 97   merged_1000_VUX_PUCK  chunk_1097__chunk_1098      ❌
# 98   merged_1000_VUX_PUCK  chunk_1098__chunk_1099      ❌
# 99   merged_1000_VUX_PUCK  chunk_1099__chunk_1100      ❌
# 100  merged_1000_VUX_PUCK  chunk_1100__chunk_1101      ❌
# 101  merged_1000_VUX_PUCK  chunk_1101__chunk_1102      ❌
# 102  merged_1000_VUX_PUCK  chunk_1102__chunk_1103      ❌
# 103  merged_1000_VUX_PUCK  chunk_1103__chunk_1104      ❌
# 104  merged_1000_VUX_PUCK  chunk_1104__chunk_1105      ❌
# 105  merged_1000_VUX_PUCK  chunk_1105__chunk_1106      ❌
# 106  merged_1000_VUX_PUCK  chunk_1106__chunk_1107      ❌
# 107  merged_1000_VUX_PUCK  chunk_1107__chunk_1108      ❌
# 108  merged_1000_VUX_PUCK  chunk_1108__chunk_1109      ✅
# 109  merged_1000_VUX_PUCK  chunk_1109__chunk_1110      ✅
# 110  merged_1000_VUX_PUCK  chunk_1110__chunk_1111      ✅
# 111  merged_1000_VUX_PUCK  chunk_1111__chunk_1112      ✅
# 112  merged_1000_VUX_PUCK  chunk_1112__chunk_1113      ✅
# 113  merged_1000_VUX_PUCK  chunk_1113__chunk_1114      ❌
# 114  merged_1000_VUX_PUCK  chunk_1114__chunk_1115      ✅
# 115  merged_1000_VUX_PUCK  chunk_1115__chunk_1116      ✅
# 116  merged_1000_VUX_PUCK  chunk_1116__chunk_1117      ✅
# 117  merged_1000_VUX_PUCK  chunk_1117__chunk_1118      ✅
# 118  merged_1000_VUX_PUCK  chunk_1118__chunk_1119      ❌
# 119  merged_1000_VUX_PUCK  chunk_1119__chunk_1120      ✅
# 120  merged_1000_VUX_PUCK  chunk_1120__chunk_1121      ✅
# 121  merged_1000_VUX_PUCK  chunk_1121__chunk_1122      ✅
# 122  merged_1000_VUX_PUCK  chunk_1122__chunk_1123      ❌
# 123  merged_1000_VUX_PUCK  chunk_1123__chunk_1124      ✅
# 124  merged_1000_VUX_PUCK  chunk_1124__chunk_1125      ✅
# 125  merged_1000_VUX_PUCK  chunk_1125__chunk_1126      ✅
# 126  merged_1000_VUX_PUCK  chunk_1126__chunk_1127      ❌
# 127  merged_1000_VUX_PUCK  chunk_1127__chunk_1128      ✅
# 128  merged_1000_VUX_PUCK  chunk_1128__chunk_1129      ✅
# 129  merged_1000_VUX_PUCK  chunk_1129__chunk_1130      ❌
# 130  merged_1000_VUX_PUCK  chunk_1130__chunk_1131      ✅
# 131  merged_1000_VUX_PUCK  chunk_1131__chunk_1132      ✅
# 132  merged_1000_VUX_PUCK  chunk_1132__chunk_1133      ✅
# 133  merged_1000_VUX_PUCK  chunk_1133__chunk_1134      ❌
# 134  merged_1000_VUX_PUCK  chunk_1134__chunk_1135      ✅
# 135  merged_1000_VUX_PUCK  chunk_1135__chunk_1136      ✅
# 136  merged_1000_VUX_PUCK  chunk_1136__chunk_1137      ❌
# 137  merged_1000_VUX_PUCK  chunk_1137__chunk_1138      ❌
# 138  merged_1000_VUX_PUCK  chunk_1138__chunk_1139      ❌
# 139  merged_1000_VUX_PUCK  chunk_1139__chunk_1140      ❌
# 140  merged_1000_VUX_PUCK  chunk_1140__chunk_1141      ❌
# 141  merged_1000_VUX_PUCK  chunk_1141__chunk_1142      ❌
# 142  merged_1000_VUX_PUCK  chunk_1142__chunk_1143      ❌
# 143  merged_1000_VUX_PUCK  chunk_1143__chunk_1144      ✅
# 144  merged_1000_VUX_PUCK  chunk_1144__chunk_1145      ❌
# 145  merged_1000_VUX_PUCK  chunk_1145__chunk_1146      ❌
# 146  merged_1000_VUX_PUCK  chunk_1146__chunk_1147      ❌
# 147  merged_1000_VUX_PUCK  chunk_1147__chunk_1148      ❌
# 148  merged_1000_VUX_PUCK  chunk_1148__chunk_1149      ❌
# 149  merged_1000_VUX_PUCK  chunk_1149__chunk_1150      ✅
# 150  merged_1000_VUX_PUCK  chunk_1150__chunk_1151      ❌
# 151  merged_1000_VUX_PUCK  chunk_1151__chunk_1152      ❌
# 152  merged_1000_VUX_PUCK  chunk_1152__chunk_1153      ✅
# 153  merged_1000_VUX_PUCK  chunk_1153__chunk_1154      ✅
# 154  merged_1000_VUX_PUCK  chunk_1154__chunk_1155      ❌
# 155  merged_1000_VUX_PUCK  chunk_1155__chunk_1156      ✅
# 156  merged_1000_VUX_PUCK  chunk_1156__chunk_1157      ✅
# 157  merged_1000_VUX_PUCK  chunk_1157__chunk_1158      ✅
# 158  merged_1000_VUX_PUCK  chunk_1158__chunk_1159      ❌
# 159  merged_1000_VUX_PUCK  chunk_1159__chunk_1160      ❌
# 160  merged_1000_VUX_PUCK  chunk_1160__chunk_1161      ✅
# 161  merged_1000_VUX_PUCK  chunk_1161__chunk_1162      ❌
# 162  merged_1000_VUX_PUCK  chunk_1162__chunk_1163      ❌
# 163  merged_1000_VUX_PUCK  chunk_1163__chunk_1164      ❌
# 164  merged_1000_VUX_PUCK  chunk_1164__chunk_1165      ✅
# 165  merged_1000_VUX_PUCK  chunk_1165__chunk_1166      ❌
# 166  merged_1000_VUX_PUCK  chunk_1166__chunk_1167      ❌
# 167  merged_1000_VUX_PUCK  chunk_1167__chunk_1168      ✅
# 168  merged_1000_VUX_PUCK  chunk_1168__chunk_1169      ✅
# 169  merged_1000_VUX_PUCK  chunk_1169__chunk_1170      ❌
# 170  merged_1000_VUX_PUCK  chunk_1170__chunk_1171      ❌
# 171  merged_1000_VUX_PUCK  chunk_1171__chunk_1172      ✅
# 172  merged_1000_VUX_PUCK  chunk_1172__chunk_1173      ✅
# 173  merged_1000_VUX_PUCK  chunk_1173__chunk_1174      ✅
# 174  merged_1000_VUX_PUCK  chunk_1174__chunk_1175      ✅
# 175  merged_1000_VUX_PUCK  chunk_1175__chunk_1176      ❌
# 176  merged_1000_VUX_PUCK  chunk_1176__chunk_1177      ❌
# 177  merged_1000_VUX_PUCK  chunk_1177__chunk_1178      ✅
# 178  merged_1000_VUX_PUCK  chunk_1178__chunk_1179      ✅
# 179  merged_1000_VUX_PUCK  chunk_1179__chunk_1180      ✅
# 180  merged_1000_VUX_PUCK  chunk_1180__chunk_1181      ✅
# 181  merged_1000_VUX_PUCK  chunk_1181__chunk_1182      ✅
# 182  merged_1000_VUX_PUCK  chunk_1182__chunk_1183      ✅
# 183  merged_1000_VUX_PUCK  chunk_1183__chunk_1184      ✅
# 184  merged_1000_VUX_PUCK  chunk_1184__chunk_1185      ✅
# 185  merged_1000_VUX_PUCK  chunk_1185__chunk_1186      ✅
# 186  merged_1000_VUX_PUCK  chunk_1186__chunk_1187      ✅
# 187  merged_1000_VUX_PUCK  chunk_1187__chunk_1188      ✅
# 188  merged_1000_VUX_PUCK  chunk_1188__chunk_1189      ✅
# 189  merged_1000_VUX_PUCK  chunk_1189__chunk_1190      ✅
# 190  merged_1000_VUX_PUCK  chunk_1190__chunk_1191      ✅
# 191  merged_1000_VUX_PUCK  chunk_1191__chunk_1192      ✅
# 192  merged_1000_VUX_PUCK  chunk_1192__chunk_1193      ✅
# 193  merged_1000_VUX_PUCK  chunk_1193__chunk_1194      ✅
# 194  merged_1000_VUX_PUCK  chunk_1194__chunk_1195      ✅
# 195  merged_1000_VUX_PUCK  chunk_1195__chunk_1196      ❌
# 196  merged_1000_VUX_PUCK  chunk_1196__chunk_1197      ❌
# 197  merged_1000_VUX_PUCK  chunk_1197__chunk_1198      ✅
# 198  merged_1000_VUX_PUCK  chunk_1198__chunk_1199      ❌
# 199  merged_1000_VUX_PUCK  chunk_1199__chunk_1200      ✅
# 200  merged_1000_VUX_PUCK  chunk_1200__chunk_1201      ✅
# 201  merged_1000_VUX_PUCK  chunk_1201__chunk_1202      ✅
# 202  merged_1000_VUX_PUCK  chunk_1202__chunk_1203      ✅
# 203  merged_1000_VUX_PUCK  chunk_1203__chunk_1204      ✅
# 204  merged_1000_VUX_PUCK  chunk_1204__chunk_1205      ✅
# 205  merged_2000_VUX_PUCK  chunk_1205__chunk_2000      ✅
# 206  merged_2000_VUX_PUCK  chunk_2000__chunk_2001      ✅
# 207  merged_2000_VUX_PUCK  chunk_2001__chunk_2002      ✅
# 208  merged_2000_VUX_PUCK  chunk_2002__chunk_2003      ✅
# 209  merged_2000_VUX_PUCK  chunk_2003__chunk_2004      ✅
# 210  merged_2000_VUX_PUCK  chunk_2004__chunk_2005      ✅
# 211  merged_2000_VUX_PUCK  chunk_2005__chunk_2006      ✅
# 212  merged_2000_VUX_PUCK  chunk_2006__chunk_2007      ✅
# 213  merged_2000_VUX_PUCK  chunk_2007__chunk_2008      ✅
# 214  merged_2000_VUX_PUCK  chunk_2008__chunk_2009      ✅
# 215  merged_2000_VUX_PUCK  chunk_2009__chunk_2010      ✅
# 216  merged_2000_VUX_PUCK  chunk_2010__chunk_2011      ✅
# 217  merged_2000_VUX_PUCK  chunk_2011__chunk_2012      ✅
# 218  merged_2000_VUX_PUCK  chunk_2012__chunk_2013      ✅
# 219  merged_2000_VUX_PUCK  chunk_2013__chunk_2014      ✅
# 220  merged_2000_VUX_PUCK  chunk_2014__chunk_2015      ✅
# 221  merged_2000_VUX_PUCK  chunk_2015__chunk_2016      ✅
# 222  merged_2000_VUX_PUCK  chunk_2016__chunk_2017      ✅
# 223  merged_2000_VUX_PUCK  chunk_2017__chunk_2018      ✅
# 224  merged_2000_VUX_PUCK  chunk_2018__chunk_2019      ✅
# 225  merged_2000_VUX_PUCK  chunk_2019__chunk_2020      ✅
# 226  merged_2000_VUX_PUCK  chunk_2020__chunk_2021      ✅
# 227  merged_2000_VUX_PUCK  chunk_2021__chunk_2022      ✅
# 228  merged_2000_VUX_PUCK  chunk_2022__chunk_2023      ✅
# 229  merged_2000_VUX_PUCK  chunk_2023__chunk_2024      ✅
# 230  merged_2000_VUX_PUCK  chunk_2024__chunk_2025      ✅
# 231  merged_2000_VUX_PUCK  chunk_2025__chunk_2026      ✅
# 232  merged_2000_VUX_PUCK  chunk_2026__chunk_2027      ✅
# 233  merged_2000_VUX_PUCK  chunk_2027__chunk_2028      ✅
# 234  merged_2000_VUX_PUCK  chunk_2028__chunk_2029      ✅
# 235  merged_2000_VUX_PUCK  chunk_2029__chunk_2030      ✅
# 236  merged_2000_VUX_PUCK  chunk_2030__chunk_2031      ✅
# 237  merged_2000_VUX_PUCK  chunk_2031__chunk_2032      ✅
# 238  merged_2000_VUX_PUCK  chunk_2032__chunk_2033      ✅
# 239  merged_2000_VUX_PUCK  chunk_2033__chunk_2034      ✅
# 240  merged_2000_VUX_PUCK  chunk_2034__chunk_2035      ✅
# 241  merged_2000_VUX_PUCK  chunk_2035__chunk_2036      ❌
# 242  merged_2000_VUX_PUCK  chunk_2036__chunk_2037      ✅
# 243  merged_2000_VUX_PUCK  chunk_2037__chunk_2038      ❌
# 244  merged_2000_VUX_PUCK  chunk_2038__chunk_2039      ❌
# 245  merged_2000_VUX_PUCK  chunk_2039__chunk_2040      ✅
# 246  merged_2000_VUX_PUCK  chunk_2040__chunk_2041      ✅
# 247  merged_2000_VUX_PUCK  chunk_2041__chunk_2042      ✅
# 248  merged_2000_VUX_PUCK  chunk_2042__chunk_2043      ✅
# 249  merged_2000_VUX_PUCK  chunk_2043__chunk_2044      ✅
# 250  merged_2000_VUX_PUCK  chunk_2044__chunk_2045      ✅
# 251  merged_2000_VUX_PUCK  chunk_2045__chunk_2046      ✅
# 252  merged_2000_VUX_PUCK  chunk_2046__chunk_2047      ✅
# 253  merged_2000_VUX_PUCK  chunk_2047__chunk_2048      ❌
# 254  merged_2000_VUX_PUCK  chunk_2048__chunk_2049      ✅
# 255  merged_2000_VUX_PUCK  chunk_2049__chunk_2050      ❌
# 256  merged_2000_VUX_PUCK  chunk_2050__chunk_2051      ❌
# 257  merged_2000_VUX_PUCK  chunk_2051__chunk_2052      ❌
# 258  merged_2000_VUX_PUCK  chunk_2052__chunk_2053      ❌
# 259  merged_2000_VUX_PUCK  chunk_2053__chunk_2054      ✅
# 260  merged_2000_VUX_PUCK  chunk_2054__chunk_2055      ✅
# 261  merged_2000_VUX_PUCK  chunk_2055__chunk_2056      ❌
# 262  merged_2000_VUX_PUCK  chunk_2056__chunk_2057      ✅
# 263  merged_2000_VUX_PUCK  chunk_2057__chunk_2058      ❌
# 264  merged_2000_VUX_PUCK  chunk_2058__chunk_2059      ❌
# 265  merged_2000_VUX_PUCK  chunk_2059__chunk_2060      ✅
# 266  merged_2000_VUX_PUCK  chunk_2060__chunk_2061      ❌
# 267  merged_3000_VUX_PUCK  chunk_2061__chunk_3000      ✅
# 268  merged_3000_VUX_PUCK  chunk_3000__chunk_3001      ✅
# 269  merged_3000_VUX_PUCK  chunk_3001__chunk_3002      ✅
# 270  merged_3000_VUX_PUCK  chunk_3002__chunk_3003      ✅
# 271  merged_3000_VUX_PUCK  chunk_3003__chunk_3004      ✅
# 272  merged_3000_VUX_PUCK  chunk_3004__chunk_3005      ✅
# 273  merged_3000_VUX_PUCK  chunk_3005__chunk_3006      ✅
# 274  merged_3000_VUX_PUCK  chunk_3006__chunk_3007      ✅
# 275  merged_3000_VUX_PUCK  chunk_3007__chunk_3008      ✅
# 276  merged_3000_VUX_PUCK  chunk_3008__chunk_3009      ✅
# 277  merged_3000_VUX_PUCK  chunk_3009__chunk_3010      ✅
# 278  merged_3000_VUX_PUCK  chunk_3010__chunk_3011      ✅
# 279  merged_3000_VUX_PUCK  chunk_3011__chunk_3012      ✅
# 280  merged_3000_VUX_PUCK  chunk_3012__chunk_3013      ✅
# 281  merged_3000_VUX_PUCK  chunk_3013__chunk_3014      ✅
# 282  merged_3000_VUX_PUCK  chunk_3014__chunk_3015      ✅
# 283  merged_3000_VUX_PUCK  chunk_3015__chunk_3016      ✅
# 284  merged_3000_VUX_PUCK  chunk_3016__chunk_3017      ✅
# 285  merged_3000_VUX_PUCK  chunk_3017__chunk_3018      ✅
# 286  merged_3000_VUX_PUCK  chunk_3018__chunk_3019      ✅
# 287  merged_3000_VUX_PUCK  chunk_3019__chunk_3020      ✅
# 288  merged_3000_VUX_PUCK  chunk_3020__chunk_3021      ✅
# 289  merged_3000_VUX_PUCK  chunk_3021__chunk_3022      ✅
# 290  merged_3000_VUX_PUCK  chunk_3022__chunk_3023      ✅
# 291  merged_3000_VUX_PUCK  chunk_3023__chunk_3024      ✅
# 292  merged_3000_VUX_PUCK  chunk_3024__chunk_3025      ✅
# 293  merged_3000_VUX_PUCK  chunk_3025__chunk_3026      ✅
# 294  merged_3000_VUX_PUCK  chunk_3026__chunk_3027      ✅
# 295  merged_3000_VUX_PUCK  chunk_3027__chunk_3028      ✅
# 296  merged_3000_VUX_PUCK  chunk_3028__chunk_3029      ✅
# 297  merged_3000_VUX_PUCK  chunk_3029__chunk_3030      ✅
# 298  merged_3000_VUX_PUCK  chunk_3030__chunk_3031      ✅
# 299  merged_3000_VUX_PUCK  chunk_3031__chunk_3032      ✅
# 300  merged_3000_VUX_PUCK  chunk_3032__chunk_3033      ✅
# 301  merged_3000_VUX_PUCK  chunk_3033__chunk_3034      ✅
# 302  merged_3000_VUX_PUCK  chunk_3034__chunk_3035      ✅
# 303  merged_3000_VUX_PUCK  chunk_3035__chunk_3036      ✅
# 304  merged_3000_VUX_PUCK  chunk_3036__chunk_3037      ✅
# 305  merged_3000_VUX_PUCK  chunk_3037__chunk_3038      ✅
# 306  merged_3000_VUX_PUCK  chunk_3038__chunk_3039      ✅
# 307  merged_3000_VUX_PUCK  chunk_3039__chunk_3040      ✅
# 308  merged_3000_VUX_PUCK  chunk_3040__chunk_3041      ✅
# 309  merged_3000_VUX_PUCK  chunk_3041__chunk_3042      ✅
# 310  merged_3000_VUX_PUCK  chunk_3042__chunk_3043      ✅
# 311  merged_3000_VUX_PUCK  chunk_3043__chunk_3044      ✅
# 312  merged_3000_VUX_PUCK  chunk_3044__chunk_3045      ✅
# 313  merged_3000_VUX_PUCK  chunk_3045__chunk_3046      ✅
# 314  merged_3000_VUX_PUCK  chunk_3046__chunk_3047      ✅
# 315  merged_3000_VUX_PUCK  chunk_3047__chunk_3048      ✅
# 316  merged_3000_VUX_PUCK  chunk_3048__chunk_3049      ✅
# 317  merged_3000_VUX_PUCK  chunk_3049__chunk_3050      ✅
# 318  merged_3000_VUX_PUCK  chunk_3050__chunk_3051      ✅
# 319  merged_3000_VUX_PUCK  chunk_3051__chunk_3052      ✅
# 320  merged_3000_VUX_PUCK  chunk_3052__chunk_3053      ✅
# 321  merged_3000_VUX_PUCK  chunk_3053__chunk_3054      ✅
# 322  merged_3000_VUX_PUCK  chunk_3054__chunk_3055      ✅
# 323  merged_3000_VUX_PUCK  chunk_3055__chunk_3056      ✅
# 324  merged_3000_VUX_PUCK  chunk_3056__chunk_3057      ✅
# 325  merged_3000_VUX_PUCK  chunk_3057__chunk_3058      ✅
# 326  merged_3000_VUX_PUCK  chunk_3058__chunk_3059      ✅
# 327  merged_3000_VUX_PUCK  chunk_3059__chunk_3060      ✅
# 328  merged_3000_VUX_PUCK  chunk_3060__chunk_3061      ✅
# 329  merged_3000_VUX_PUCK  chunk_3061__chunk_3062      ✅
# 330  merged_3000_VUX_PUCK  chunk_3062__chunk_3063      ✅
# 331  merged_3000_VUX_PUCK  chunk_3063__chunk_3064      ✅
# 332  merged_3000_VUX_PUCK  chunk_3064__chunk_3065      ✅
# 333  merged_3000_VUX_PUCK  chunk_3065__chunk_3066      ✅
# 334  merged_3000_VUX_PUCK  chunk_3066__chunk_3067      ✅
# 335  merged_3000_VUX_PUCK  chunk_3067__chunk_3068      ❌
# 336  merged_3000_VUX_PUCK  chunk_3068__chunk_3069      ✅
# 337  merged_3000_VUX_PUCK  chunk_3069__chunk_3070      ✅
# 338  merged_3000_VUX_PUCK  chunk_3070__chunk_3071      ✅
# 339  merged_3000_VUX_PUCK  chunk_3071__chunk_3072      ✅
# 340  merged_3000_VUX_PUCK  chunk_3072__chunk_3073      ✅
# 341  merged_3000_VUX_PUCK  chunk_3073__chunk_3074      ✅
# 342  merged_3000_VUX_PUCK  chunk_3074__chunk_3075      ✅
# 343  merged_3000_VUX_PUCK  chunk_3075__chunk_3076      ✅
# 344  merged_3000_VUX_PUCK  chunk_3076__chunk_3077      ✅
# 345  merged_3000_VUX_PUCK  chunk_3077__chunk_3078      ✅
# 346  merged_3000_VUX_PUCK  chunk_3078__chunk_3079      ✅
# 347  merged_3000_VUX_PUCK  chunk_3079__chunk_3080      ✅
# 348  merged_3000_VUX_PUCK  chunk_3080__chunk_3081      ✅
# 349  merged_3000_VUX_PUCK  chunk_3081__chunk_3082      ✅
# 350  merged_3000_VUX_PUCK  chunk_3082__chunk_3083      ✅
# 351  merged_3000_VUX_PUCK  chunk_3083__chunk_3084      ✅
# 352  merged_3000_VUX_PUCK  chunk_3084__chunk_3085      ✅
# 353  merged_3000_VUX_PUCK  chunk_3085__chunk_3086      ✅
# 354  merged_3000_VUX_PUCK  chunk_3086__chunk_3087      ✅
# 355  merged_3000_VUX_PUCK  chunk_3087__chunk_3088      ✅
# 356  merged_3000_VUX_PUCK  chunk_3088__chunk_3089      ✅
# 357  merged_3000_VUX_PUCK  chunk_3089__chunk_3090      ✅
# 358  merged_3000_VUX_PUCK  chunk_3090__chunk_3091      ✅
# 359  merged_3000_VUX_PUCK  chunk_3091__chunk_3092      ✅
# 360  merged_3000_VUX_PUCK  chunk_3092__chunk_3093      ✅
# 361  merged_3000_VUX_PUCK  chunk_3093__chunk_3094      ✅
# 362  merged_3000_VUX_PUCK  chunk_3094__chunk_3095      ✅
# 363  merged_3000_VUX_PUCK  chunk_3095__chunk_3096      ✅
# 364  merged_3000_VUX_PUCK  chunk_3096__chunk_3097      ✅
# 365  merged_3000_VUX_PUCK  chunk_3097__chunk_3098      ✅
# 366  merged_3000_VUX_PUCK  chunk_3098__chunk_3099      ✅
# 367  merged_3000_VUX_PUCK  chunk_3099__chunk_3100      ✅
# 368  merged_3000_VUX_PUCK  chunk_3100__chunk_3101      ✅
# 369  merged_3000_VUX_PUCK  chunk_3101__chunk_3102      ✅
# 370  merged_3000_VUX_PUCK  chunk_3102__chunk_3103      ✅
# 371  merged_3000_VUX_PUCK  chunk_3103__chunk_3104      ✅
# 372  merged_3000_VUX_PUCK  chunk_3104__chunk_3105      ❌
# 373  merged_3000_VUX_PUCK  chunk_3105__chunk_3106      ✅
# 374  merged_3000_VUX_PUCK  chunk_3106__chunk_3107      ✅
# 375  merged_3000_VUX_PUCK  chunk_3107__chunk_3108      ✅
# 376  merged_3000_VUX_PUCK  chunk_3108__chunk_3109      ✅
# 377  merged_3000_VUX_PUCK  chunk_3109__chunk_3110      ✅
# 378  merged_3000_VUX_PUCK  chunk_3110__chunk_3111      ✅
# 379  merged_3000_VUX_PUCK  chunk_3111__chunk_3112      ✅
# 380  merged_3000_VUX_PUCK  chunk_3112__chunk_3113      ✅
# 381  merged_3000_VUX_PUCK  chunk_3113__chunk_3114      ❌
# 382  merged_3000_VUX_PUCK  chunk_3114__chunk_3115      ✅
# 383  merged_3000_VUX_PUCK  chunk_3115__chunk_3116      ✅
# 384  merged_3000_VUX_PUCK  chunk_3116__chunk_3117      ✅
# 385  merged_3000_VUX_PUCK  chunk_3117__chunk_3118      ✅
# 386  merged_3000_VUX_PUCK  chunk_3118__chunk_3119      ❌
# 387  merged_3000_VUX_PUCK  chunk_3119__chunk_3120      ❌
# 388  merged_3000_VUX_PUCK  chunk_3120__chunk_3121      ✅
# 389  merged_3000_VUX_PUCK  chunk_3121__chunk_3122      ✅
# 390  merged_3000_VUX_PUCK  chunk_3122__chunk_3123      ✅
# 391  merged_3000_VUX_PUCK  chunk_3123__chunk_3124      ✅
# 392  merged_3000_VUX_PUCK  chunk_3124__chunk_3125      ✅
# 393  merged_3000_VUX_PUCK  chunk_3125__chunk_3126      ✅
# 394  merged_3000_VUX_PUCK  chunk_3126__chunk_3127      ❌
# 395  merged_3000_VUX_PUCK  chunk_3127__chunk_3128      ✅
# 396  merged_3000_VUX_PUCK  chunk_3128__chunk_3129      ✅
# 397  merged_3000_VUX_PUCK  chunk_3129__chunk_3130      ✅
# 398  merged_3000_VUX_PUCK  chunk_3130__chunk_3131      ✅
# 399  merged_3000_VUX_PUCK  chunk_3131__chunk_3132      ✅
# 400  merged_3000_VUX_PUCK  chunk_3132__chunk_3133      ✅
# 401  merged_3000_VUX_PUCK  chunk_3133__chunk_3134      ✅
# 402  merged_3000_VUX_PUCK  chunk_3134__chunk_3135      ✅
# 403  merged_3000_VUX_PUCK  chunk_3135__chunk_3136      ✅
# 404  merged_3000_VUX_PUCK  chunk_3136__chunk_3137      ✅
# 405  merged_3000_VUX_PUCK  chunk_3137__chunk_3138      ✅
# 406  merged_3000_VUX_PUCK  chunk_3138__chunk_3139      ✅
# 407  merged_3000_VUX_PUCK  chunk_3139__chunk_3140      ✅
# 408  merged_3000_VUX_PUCK  chunk_3140__chunk_3141      ✅
# 409  merged_3000_VUX_PUCK  chunk_3141__chunk_3142      ✅
# 410  merged_3000_VUX_PUCK  chunk_3142__chunk_3143      ✅
# 411  merged_3000_VUX_PUCK  chunk_3143__chunk_3144      ✅
# 412  merged_3000_VUX_PUCK  chunk_3144__chunk_3145      ✅
# 413  merged_3000_VUX_PUCK  chunk_3145__chunk_3146      ✅
# 414  merged_3000_VUX_PUCK  chunk_3146__chunk_3147      ✅
# 415  merged_3000_VUX_PUCK  chunk_3147__chunk_3148      ✅
# 416  merged_3000_VUX_PUCK  chunk_3148__chunk_3149      ✅
# 417  merged_3000_VUX_PUCK  chunk_3149__chunk_3150      ✅
# 418  merged_3000_VUX_PUCK  chunk_3150__chunk_3151      ✅
# 419  merged_3000_VUX_PUCK  chunk_3151__chunk_3152      ✅
# 420  merged_3000_VUX_PUCK  chunk_3152__chunk_3153      ✅
# 421  merged_3000_VUX_PUCK  chunk_3153__chunk_3154      ✅
# 422  merged_3000_VUX_PUCK  chunk_3154__chunk_3155      ✅
# 423  merged_3000_VUX_PUCK  chunk_3155__chunk_3156      ✅
# 424  merged_3000_VUX_PUCK  chunk_3156__chunk_3157      ✅
# 425  merged_3000_VUX_PUCK  chunk_3157__chunk_3158      ✅
# 426  merged_3000_VUX_PUCK  chunk_3158__chunk_3159      ✅
# 427  merged_3000_VUX_PUCK  chunk_3159__chunk_3160      ✅
# 428  merged_3000_VUX_PUCK  chunk_3160__chunk_3161      ✅
# 429  merged_3000_VUX_PUCK  chunk_3161__chunk_3162      ✅
# 430  merged_3000_VUX_PUCK  chunk_3162__chunk_3163      ❌
# 431  merged_3000_VUX_PUCK  chunk_3163__chunk_3164      ✅
# 432  merged_3000_VUX_PUCK  chunk_3164__chunk_3165      ❌
# 433  merged_3000_VUX_PUCK  chunk_3165__chunk_3166      ❌
# 434  merged_3000_VUX_PUCK  chunk_3166__chunk_3167      ❌
# 435  merged_3000_VUX_PUCK  chunk_3167__chunk_3168      ❌
#
#                                       detail
# 0    LiDAR_p2p_rsc_chunk_1000_chunk_1001.txt
# 1                         aucun fichier .txt
# 2                         aucun fichier .txt
# 3    LiDAR_p2p_rsc_chunk_1003_chunk_1004.txt
# 4                         aucun fichier .txt
# 5                         aucun fichier .txt
# 6                         aucun fichier .txt
# 7                         aucun fichier .txt
# 8    LiDAR_p2p_rsc_chunk_1008_chunk_1009.txt
# 9    LiDAR_p2p_rsc_chunk_1009_chunk_1010.txt
# 10   LiDAR_p2p_rsc_chunk_1010_chunk_1011.txt
# 11   LiDAR_p2p_rsc_chunk_1011_chunk_1012.txt
# 12   LiDAR_p2p_rsc_chunk_1012_chunk_1013.txt
# 13                        aucun fichier .txt
# 14                        aucun fichier .txt
# 15                        aucun fichier .txt
# 16   LiDAR_p2p_rsc_chunk_1016_chunk_1017.txt
# 17   LiDAR_p2p_rsc_chunk_1017_chunk_1018.txt
# 18                        aucun fichier .txt
# 19   LiDAR_p2p_rsc_chunk_1019_chunk_1020.txt
# 20                        aucun fichier .txt
# 21   LiDAR_p2p_rsc_chunk_1021_chunk_1022.txt
# 22   LiDAR_p2p_rsc_chunk_1022_chunk_1023.txt
# 23                        aucun fichier .txt
# 24                        aucun fichier .txt
# 25   LiDAR_p2p_rsc_chunk_1025_chunk_1026.txt
# 26   LiDAR_p2p_rsc_chunk_1026_chunk_1027.txt
# 27   LiDAR_p2p_rsc_chunk_1027_chunk_1028.txt
# 28   LiDAR_p2p_rsc_chunk_1028_chunk_1029.txt
# 29   LiDAR_p2p_rsc_chunk_1029_chunk_1030.txt
# 30   LiDAR_p2p_rsc_chunk_1030_chunk_1031.txt
# 31   LiDAR_p2p_rsc_chunk_1031_chunk_1032.txt
# 32   LiDAR_p2p_rsc_chunk_1032_chunk_1033.txt
# 33   LiDAR_p2p_rsc_chunk_1033_chunk_1034.txt
# 34   LiDAR_p2p_rsc_chunk_1034_chunk_1035.txt
# 35   LiDAR_p2p_rsc_chunk_1035_chunk_1036.txt
# 36   LiDAR_p2p_rsc_chunk_1036_chunk_1037.txt
# 37   LiDAR_p2p_rsc_chunk_1037_chunk_1038.txt
# 38   LiDAR_p2p_rsc_chunk_1038_chunk_1039.txt
# 39                        aucun fichier .txt
# 40   LiDAR_p2p_rsc_chunk_1040_chunk_1041.txt
# 41   LiDAR_p2p_rsc_chunk_1041_chunk_1042.txt
# 42   LiDAR_p2p_rsc_chunk_1042_chunk_1043.txt
# 43   LiDAR_p2p_rsc_chunk_1043_chunk_1044.txt
# 44   LiDAR_p2p_rsc_chunk_1044_chunk_1045.txt
# 45   LiDAR_p2p_rsc_chunk_1045_chunk_1046.txt
# 46   LiDAR_p2p_rsc_chunk_1046_chunk_1047.txt
# 47   LiDAR_p2p_rsc_chunk_1047_chunk_1048.txt
# 48   LiDAR_p2p_rsc_chunk_1048_chunk_1049.txt
# 49                        aucun fichier .txt
# 50   LiDAR_p2p_rsc_chunk_1050_chunk_1051.txt
# 51   LiDAR_p2p_rsc_chunk_1051_chunk_1052.txt
# 52   LiDAR_p2p_rsc_chunk_1052_chunk_1053.txt
# 53   LiDAR_p2p_rsc_chunk_1053_chunk_1054.txt
# 54   LiDAR_p2p_rsc_chunk_1054_chunk_1055.txt
# 55   LiDAR_p2p_rsc_chunk_1055_chunk_1056.txt
# 56   LiDAR_p2p_rsc_chunk_1056_chunk_1057.txt
# 57   LiDAR_p2p_rsc_chunk_1057_chunk_1058.txt
# 58   LiDAR_p2p_rsc_chunk_1058_chunk_1059.txt
# 59   LiDAR_p2p_rsc_chunk_1059_chunk_1060.txt
# 60   LiDAR_p2p_rsc_chunk_1060_chunk_1061.txt
# 61   LiDAR_p2p_rsc_chunk_1061_chunk_1062.txt
# 62   LiDAR_p2p_rsc_chunk_1062_chunk_1063.txt
# 63   LiDAR_p2p_rsc_chunk_1063_chunk_1064.txt
# 64                        aucun fichier .txt
# 65   LiDAR_p2p_rsc_chunk_1065_chunk_1066.txt
# 66   LiDAR_p2p_rsc_chunk_1066_chunk_1067.txt
# 67   LiDAR_p2p_rsc_chunk_1067_chunk_1068.txt
# 68   LiDAR_p2p_rsc_chunk_1068_chunk_1069.txt
# 69   LiDAR_p2p_rsc_chunk_1069_chunk_1070.txt
# 70   LiDAR_p2p_rsc_chunk_1070_chunk_1071.txt
# 71   LiDAR_p2p_rsc_chunk_1071_chunk_1072.txt
# 72   LiDAR_p2p_rsc_chunk_1072_chunk_1073.txt
# 73   LiDAR_p2p_rsc_chunk_1073_chunk_1074.txt
# 74   LiDAR_p2p_rsc_chunk_1074_chunk_1075.txt
# 75   LiDAR_p2p_rsc_chunk_1075_chunk_1076.txt
# 76   LiDAR_p2p_rsc_chunk_1076_chunk_1077.txt
# 77   LiDAR_p2p_rsc_chunk_1077_chunk_1078.txt
# 78   LiDAR_p2p_rsc_chunk_1078_chunk_1079.txt
# 79   LiDAR_p2p_rsc_chunk_1079_chunk_1080.txt
# 80                        aucun fichier .txt
# 81                        aucun fichier .txt
# 82   LiDAR_p2p_rsc_chunk_1082_chunk_1083.txt
# 83   LiDAR_p2p_rsc_chunk_1083_chunk_1084.txt
# 84                        aucun fichier .txt
# 85                        aucun fichier .txt
# 86                        aucun fichier .txt
# 87                        aucun fichier .txt
# 88                        aucun fichier .txt
# 89                        aucun fichier .txt
# 90                        aucun fichier .txt
# 91   LiDAR_p2p_rsc_chunk_1091_chunk_1092.txt
# 92                        aucun fichier .txt
# 93                        aucun fichier .txt
# 94                        aucun fichier .txt
# 95                        aucun fichier .txt
# 96                        aucun fichier .txt
# 97                        aucun fichier .txt
# 98                        aucun fichier .txt
# 99                        aucun fichier .txt
# 100                       aucun fichier .txt
# 101                       aucun fichier .txt
# 102                       aucun fichier .txt
# 103                       aucun fichier .txt
# 104                       aucun fichier .txt
# 105                       aucun fichier .txt
# 106                       aucun fichier .txt
# 107                       aucun fichier .txt
# 108  LiDAR_p2p_rsc_chunk_1108_chunk_1109.txt
# 109  LiDAR_p2p_rsc_chunk_1109_chunk_1110.txt
# 110  LiDAR_p2p_rsc_chunk_1110_chunk_1111.txt
# 111  LiDAR_p2p_rsc_chunk_1111_chunk_1112.txt
# 112  LiDAR_p2p_rsc_chunk_1112_chunk_1113.txt
# 113                       aucun fichier .txt
# 114  LiDAR_p2p_rsc_chunk_1114_chunk_1115.txt
# 115  LiDAR_p2p_rsc_chunk_1115_chunk_1116.txt
# 116  LiDAR_p2p_rsc_chunk_1116_chunk_1117.txt
# 117  LiDAR_p2p_rsc_chunk_1117_chunk_1118.txt
# 118                       aucun fichier .txt
# 119  LiDAR_p2p_rsc_chunk_1119_chunk_1120.txt
# 120  LiDAR_p2p_rsc_chunk_1120_chunk_1121.txt
# 121  LiDAR_p2p_rsc_chunk_1121_chunk_1122.txt
# 122                       aucun fichier .txt
# 123  LiDAR_p2p_rsc_chunk_1123_chunk_1124.txt
# 124  LiDAR_p2p_rsc_chunk_1124_chunk_1125.txt
# 125  LiDAR_p2p_rsc_chunk_1125_chunk_1126.txt
# 126                       aucun fichier .txt
# 127  LiDAR_p2p_rsc_chunk_1127_chunk_1128.txt
# 128  LiDAR_p2p_rsc_chunk_1128_chunk_1129.txt
# 129                       aucun fichier .txt
# 130  LiDAR_p2p_rsc_chunk_1130_chunk_1131.txt
# 131  LiDAR_p2p_rsc_chunk_1131_chunk_1132.txt
# 132  LiDAR_p2p_rsc_chunk_1132_chunk_1133.txt
# 133                       aucun fichier .txt
# 134  LiDAR_p2p_rsc_chunk_1134_chunk_1135.txt
# 135  LiDAR_p2p_rsc_chunk_1135_chunk_1136.txt
# 136                       aucun fichier .txt
# 137                       aucun fichier .txt
# 138                       aucun fichier .txt
# 139                       aucun fichier .txt
# 140                       aucun fichier .txt
# 141                       aucun fichier .txt
# 142                       aucun fichier .txt
# 143  LiDAR_p2p_rsc_chunk_1143_chunk_1144.txt
# 144                       aucun fichier .txt
# 145                       aucun fichier .txt
# 146                       aucun fichier .txt
# 147                       aucun fichier .txt
# 148                       aucun fichier .txt
# 149  LiDAR_p2p_rsc_chunk_1149_chunk_1150.txt
# 150                       aucun fichier .txt
# 151                       aucun fichier .txt
# 152  LiDAR_p2p_rsc_chunk_1152_chunk_1153.txt
# 153  LiDAR_p2p_rsc_chunk_1153_chunk_1154.txt
# 154                       aucun fichier .txt
# 155  LiDAR_p2p_rsc_chunk_1155_chunk_1156.txt
# 156  LiDAR_p2p_rsc_chunk_1156_chunk_1157.txt
# 157  LiDAR_p2p_rsc_chunk_1157_chunk_1158.txt
# 158                       aucun fichier .txt
# 159                       aucun fichier .txt
# 160  LiDAR_p2p_rsc_chunk_1160_chunk_1161.txt
# 161                       aucun fichier .txt
# 162                       aucun fichier .txt
# 163                       aucun fichier .txt
# 164  LiDAR_p2p_rsc_chunk_1164_chunk_1165.txt
# 165                       aucun fichier .txt
# 166                       aucun fichier .txt
# 167  LiDAR_p2p_rsc_chunk_1167_chunk_1168.txt
# 168  LiDAR_p2p_rsc_chunk_1168_chunk_1169.txt
# 169                       aucun fichier .txt
# 170                       aucun fichier .txt
# 171  LiDAR_p2p_rsc_chunk_1171_chunk_1172.txt
# 172  LiDAR_p2p_rsc_chunk_1172_chunk_1173.txt
# 173  LiDAR_p2p_rsc_chunk_1173_chunk_1174.txt
# 174  LiDAR_p2p_rsc_chunk_1174_chunk_1175.txt
# 175                       aucun fichier .txt
# 176                       aucun fichier .txt
# 177  LiDAR_p2p_rsc_chunk_1177_chunk_1178.txt
# 178  LiDAR_p2p_rsc_chunk_1178_chunk_1179.txt
# 179  LiDAR_p2p_rsc_chunk_1179_chunk_1180.txt
# 180  LiDAR_p2p_rsc_chunk_1180_chunk_1181.txt
# 181  LiDAR_p2p_rsc_chunk_1181_chunk_1182.txt
# 182  LiDAR_p2p_rsc_chunk_1182_chunk_1183.txt
# 183  LiDAR_p2p_rsc_chunk_1183_chunk_1184.txt
# 184  LiDAR_p2p_rsc_chunk_1184_chunk_1185.txt
# 185  LiDAR_p2p_rsc_chunk_1185_chunk_1186.txt
# 186  LiDAR_p2p_rsc_chunk_1186_chunk_1187.txt
# 187  LiDAR_p2p_rsc_chunk_1187_chunk_1188.txt
# 188  LiDAR_p2p_rsc_chunk_1188_chunk_1189.txt
# 189  LiDAR_p2p_rsc_chunk_1189_chunk_1190.txt
# 190  LiDAR_p2p_rsc_chunk_1190_chunk_1191.txt
# 191  LiDAR_p2p_rsc_chunk_1191_chunk_1192.txt
# 192  LiDAR_p2p_rsc_chunk_1192_chunk_1193.txt
# 193  LiDAR_p2p_rsc_chunk_1193_chunk_1194.txt
# 194  LiDAR_p2p_rsc_chunk_1194_chunk_1195.txt
# 195                       aucun fichier .txt
# 196                       aucun fichier .txt
# 197  LiDAR_p2p_rsc_chunk_1197_chunk_1198.txt
# 198                       aucun fichier .txt
# 199  LiDAR_p2p_rsc_chunk_1199_chunk_1200.txt
# 200  LiDAR_p2p_rsc_chunk_1200_chunk_1201.txt
# 201  LiDAR_p2p_rsc_chunk_1201_chunk_1202.txt
# 202  LiDAR_p2p_rsc_chunk_1202_chunk_1203.txt
# 203  LiDAR_p2p_rsc_chunk_1203_chunk_1204.txt
# 204  LiDAR_p2p_rsc_chunk_1204_chunk_1205.txt
# 205  LiDAR_p2p_rsc_chunk_1205_chunk_2000.txt
# 206  LiDAR_p2p_rsc_chunk_2000_chunk_2001.txt
# 207  LiDAR_p2p_rsc_chunk_2001_chunk_2002.txt
# 208  LiDAR_p2p_rsc_chunk_2002_chunk_2003.txt
# 209  LiDAR_p2p_rsc_chunk_2003_chunk_2004.txt
# 210  LiDAR_p2p_rsc_chunk_2004_chunk_2005.txt
# 211  LiDAR_p2p_rsc_chunk_2005_chunk_2006.txt
# 212  LiDAR_p2p_rsc_chunk_2006_chunk_2007.txt
# 213  LiDAR_p2p_rsc_chunk_2007_chunk_2008.txt
# 214  LiDAR_p2p_rsc_chunk_2008_chunk_2009.txt
# 215  LiDAR_p2p_rsc_chunk_2009_chunk_2010.txt
# 216  LiDAR_p2p_rsc_chunk_2010_chunk_2011.txt
# 217  LiDAR_p2p_rsc_chunk_2011_chunk_2012.txt
# 218  LiDAR_p2p_rsc_chunk_2012_chunk_2013.txt
# 219  LiDAR_p2p_rsc_chunk_2013_chunk_2014.txt
# 220  LiDAR_p2p_rsc_chunk_2014_chunk_2015.txt
# 221  LiDAR_p2p_rsc_chunk_2015_chunk_2016.txt
# 222  LiDAR_p2p_rsc_chunk_2016_chunk_2017.txt
# 223  LiDAR_p2p_rsc_chunk_2017_chunk_2018.txt
# 224  LiDAR_p2p_rsc_chunk_2018_chunk_2019.txt
# 225  LiDAR_p2p_rsc_chunk_2019_chunk_2020.txt
# 226  LiDAR_p2p_rsc_chunk_2020_chunk_2021.txt
# 227  LiDAR_p2p_rsc_chunk_2021_chunk_2022.txt
# 228  LiDAR_p2p_rsc_chunk_2022_chunk_2023.txt
# 229  LiDAR_p2p_rsc_chunk_2023_chunk_2024.txt
# 230  LiDAR_p2p_rsc_chunk_2024_chunk_2025.txt
# 231  LiDAR_p2p_rsc_chunk_2025_chunk_2026.txt
# 232  LiDAR_p2p_rsc_chunk_2026_chunk_2027.txt
# 233  LiDAR_p2p_rsc_chunk_2027_chunk_2028.txt
# 234  LiDAR_p2p_rsc_chunk_2028_chunk_2029.txt
# 235  LiDAR_p2p_rsc_chunk_2029_chunk_2030.txt
# 236  LiDAR_p2p_rsc_chunk_2030_chunk_2031.txt
# 237  LiDAR_p2p_rsc_chunk_2031_chunk_2032.txt
# 238  LiDAR_p2p_rsc_chunk_2032_chunk_2033.txt
# 239  LiDAR_p2p_rsc_chunk_2033_chunk_2034.txt
# 240  LiDAR_p2p_rsc_chunk_2034_chunk_2035.txt
# 241                       aucun fichier .txt
# 242  LiDAR_p2p_rsc_chunk_2036_chunk_2037.txt
# 243                       aucun fichier .txt
# 244                       aucun fichier .txt
# 245  LiDAR_p2p_rsc_chunk_2039_chunk_2040.txt
# 246  LiDAR_p2p_rsc_chunk_2040_chunk_2041.txt
# 247  LiDAR_p2p_rsc_chunk_2041_chunk_2042.txt
# 248  LiDAR_p2p_rsc_chunk_2042_chunk_2043.txt
# 249  LiDAR_p2p_rsc_chunk_2043_chunk_2044.txt
# 250  LiDAR_p2p_rsc_chunk_2044_chunk_2045.txt
# 251  LiDAR_p2p_rsc_chunk_2045_chunk_2046.txt
# 252  LiDAR_p2p_rsc_chunk_2046_chunk_2047.txt
# 253                       aucun fichier .txt
# 254  LiDAR_p2p_rsc_chunk_2048_chunk_2049.txt
# 255                       aucun fichier .txt
# 256                       aucun fichier .txt
# 257                       aucun fichier .txt
# 258                       aucun fichier .txt
# 259  LiDAR_p2p_rsc_chunk_2053_chunk_2054.txt
# 260  LiDAR_p2p_rsc_chunk_2054_chunk_2055.txt
# 261                       aucun fichier .txt
# 262  LiDAR_p2p_rsc_chunk_2056_chunk_2057.txt
# 263                       aucun fichier .txt
# 264                       aucun fichier .txt
# 265  LiDAR_p2p_rsc_chunk_2059_chunk_2060.txt
# 266                       aucun fichier .txt
# 267  LiDAR_p2p_rsc_chunk_2061_chunk_3000.txt
# 268  LiDAR_p2p_rsc_chunk_3000_chunk_3001.txt
# 269  LiDAR_p2p_rsc_chunk_3001_chunk_3002.txt
# 270  LiDAR_p2p_rsc_chunk_3002_chunk_3003.txt
# 271  LiDAR_p2p_rsc_chunk_3003_chunk_3004.txt
# 272  LiDAR_p2p_rsc_chunk_3004_chunk_3005.txt
# 273  LiDAR_p2p_rsc_chunk_3005_chunk_3006.txt
# 274  LiDAR_p2p_rsc_chunk_3006_chunk_3007.txt
# 275  LiDAR_p2p_rsc_chunk_3007_chunk_3008.txt
# 276  LiDAR_p2p_rsc_chunk_3008_chunk_3009.txt
# 277  LiDAR_p2p_rsc_chunk_3009_chunk_3010.txt
# 278  LiDAR_p2p_rsc_chunk_3010_chunk_3011.txt
# 279  LiDAR_p2p_rsc_chunk_3011_chunk_3012.txt
# 280  LiDAR_p2p_rsc_chunk_3012_chunk_3013.txt
# 281  LiDAR_p2p_rsc_chunk_3013_chunk_3014.txt
# 282  LiDAR_p2p_rsc_chunk_3014_chunk_3015.txt
# 283  LiDAR_p2p_rsc_chunk_3015_chunk_3016.txt
# 284  LiDAR_p2p_rsc_chunk_3016_chunk_3017.txt
# 285  LiDAR_p2p_rsc_chunk_3017_chunk_3018.txt
# 286  LiDAR_p2p_rsc_chunk_3018_chunk_3019.txt
# 287  LiDAR_p2p_rsc_chunk_3019_chunk_3020.txt
# 288  LiDAR_p2p_rsc_chunk_3020_chunk_3021.txt
# 289  LiDAR_p2p_rsc_chunk_3021_chunk_3022.txt
# 290  LiDAR_p2p_rsc_chunk_3022_chunk_3023.txt
# 291  LiDAR_p2p_rsc_chunk_3023_chunk_3024.txt
# 292  LiDAR_p2p_rsc_chunk_3024_chunk_3025.txt
# 293  LiDAR_p2p_rsc_chunk_3025_chunk_3026.txt
# 294  LiDAR_p2p_rsc_chunk_3026_chunk_3027.txt
# 295  LiDAR_p2p_rsc_chunk_3027_chunk_3028.txt
# 296  LiDAR_p2p_rsc_chunk_3028_chunk_3029.txt
# 297  LiDAR_p2p_rsc_chunk_3029_chunk_3030.txt
# 298  LiDAR_p2p_rsc_chunk_3030_chunk_3031.txt
# 299  LiDAR_p2p_rsc_chunk_3031_chunk_3032.txt
# 300  LiDAR_p2p_rsc_chunk_3032_chunk_3033.txt
# 301  LiDAR_p2p_rsc_chunk_3033_chunk_3034.txt
# 302  LiDAR_p2p_rsc_chunk_3034_chunk_3035.txt
# 303  LiDAR_p2p_rsc_chunk_3035_chunk_3036.txt
# 304  LiDAR_p2p_rsc_chunk_3036_chunk_3037.txt
# 305  LiDAR_p2p_rsc_chunk_3037_chunk_3038.txt
# 306  LiDAR_p2p_rsc_chunk_3038_chunk_3039.txt
# 307  LiDAR_p2p_rsc_chunk_3039_chunk_3040.txt
# 308  LiDAR_p2p_rsc_chunk_3040_chunk_3041.txt
# 309  LiDAR_p2p_rsc_chunk_3041_chunk_3042.txt
# 310  LiDAR_p2p_rsc_chunk_3042_chunk_3043.txt
# 311  LiDAR_p2p_rsc_chunk_3043_chunk_3044.txt
# 312  LiDAR_p2p_rsc_chunk_3044_chunk_3045.txt
# 313  LiDAR_p2p_rsc_chunk_3045_chunk_3046.txt
# 314  LiDAR_p2p_rsc_chunk_3046_chunk_3047.txt
# 315  LiDAR_p2p_rsc_chunk_3047_chunk_3048.txt
# 316  LiDAR_p2p_rsc_chunk_3048_chunk_3049.txt
# 317  LiDAR_p2p_rsc_chunk_3049_chunk_3050.txt
# 318  LiDAR_p2p_rsc_chunk_3050_chunk_3051.txt
# 319  LiDAR_p2p_rsc_chunk_3051_chunk_3052.txt
# 320  LiDAR_p2p_rsc_chunk_3052_chunk_3053.txt
# 321  LiDAR_p2p_rsc_chunk_3053_chunk_3054.txt
# 322  LiDAR_p2p_rsc_chunk_3054_chunk_3055.txt
# 323  LiDAR_p2p_rsc_chunk_3055_chunk_3056.txt
# 324  LiDAR_p2p_rsc_chunk_3056_chunk_3057.txt
# 325  LiDAR_p2p_rsc_chunk_3057_chunk_3058.txt
# 326  LiDAR_p2p_rsc_chunk_3058_chunk_3059.txt
# 327  LiDAR_p2p_rsc_chunk_3059_chunk_3060.txt
# 328  LiDAR_p2p_rsc_chunk_3060_chunk_3061.txt
# 329  LiDAR_p2p_rsc_chunk_3061_chunk_3062.txt
# 330  LiDAR_p2p_rsc_chunk_3062_chunk_3063.txt
# 331  LiDAR_p2p_rsc_chunk_3063_chunk_3064.txt
# 332  LiDAR_p2p_rsc_chunk_3064_chunk_3065.txt
# 333  LiDAR_p2p_rsc_chunk_3065_chunk_3066.txt
# 334  LiDAR_p2p_rsc_chunk_3066_chunk_3067.txt
# 335                       aucun fichier .txt
# 336  LiDAR_p2p_rsc_chunk_3068_chunk_3069.txt
# 337  LiDAR_p2p_rsc_chunk_3069_chunk_3070.txt
# 338  LiDAR_p2p_rsc_chunk_3070_chunk_3071.txt
# 339  LiDAR_p2p_rsc_chunk_3071_chunk_3072.txt
# 340  LiDAR_p2p_rsc_chunk_3072_chunk_3073.txt
# 341  LiDAR_p2p_rsc_chunk_3073_chunk_3074.txt
# 342  LiDAR_p2p_rsc_chunk_3074_chunk_3075.txt
# 343  LiDAR_p2p_rsc_chunk_3075_chunk_3076.txt
# 344  LiDAR_p2p_rsc_chunk_3076_chunk_3077.txt
# 345  LiDAR_p2p_rsc_chunk_3077_chunk_3078.txt
# 346  LiDAR_p2p_rsc_chunk_3078_chunk_3079.txt
# 347  LiDAR_p2p_rsc_chunk_3079_chunk_3080.txt
# 348  LiDAR_p2p_rsc_chunk_3080_chunk_3081.txt
# 349  LiDAR_p2p_rsc_chunk_3081_chunk_3082.txt
# 350  LiDAR_p2p_rsc_chunk_3082_chunk_3083.txt
# 351  LiDAR_p2p_rsc_chunk_3083_chunk_3084.txt
# 352  LiDAR_p2p_rsc_chunk_3084_chunk_3085.txt
# 353  LiDAR_p2p_rsc_chunk_3085_chunk_3086.txt
# 354  LiDAR_p2p_rsc_chunk_3086_chunk_3087.txt
# 355  LiDAR_p2p_rsc_chunk_3087_chunk_3088.txt
# 356  LiDAR_p2p_rsc_chunk_3088_chunk_3089.txt
# 357  LiDAR_p2p_rsc_chunk_3089_chunk_3090.txt
# 358  LiDAR_p2p_rsc_chunk_3090_chunk_3091.txt
# 359  LiDAR_p2p_rsc_chunk_3091_chunk_3092.txt
# 360  LiDAR_p2p_rsc_chunk_3092_chunk_3093.txt
# 361  LiDAR_p2p_rsc_chunk_3093_chunk_3094.txt
# 362  LiDAR_p2p_rsc_chunk_3094_chunk_3095.txt
# 363  LiDAR_p2p_rsc_chunk_3095_chunk_3096.txt
# 364  LiDAR_p2p_rsc_chunk_3096_chunk_3097.txt
# 365  LiDAR_p2p_rsc_chunk_3097_chunk_3098.txt
# 366  LiDAR_p2p_rsc_chunk_3098_chunk_3099.txt
# 367  LiDAR_p2p_rsc_chunk_3099_chunk_3100.txt
# 368  LiDAR_p2p_rsc_chunk_3100_chunk_3101.txt
# 369  LiDAR_p2p_rsc_chunk_3101_chunk_3102.txt
# 370  LiDAR_p2p_rsc_chunk_3102_chunk_3103.txt
# 371  LiDAR_p2p_rsc_chunk_3103_chunk_3104.txt
# 372                       aucun fichier .txt
# 373  LiDAR_p2p_rsc_chunk_3105_chunk_3106.txt
# 374  LiDAR_p2p_rsc_chunk_3106_chunk_3107.txt
# 375  LiDAR_p2p_rsc_chunk_3107_chunk_3108.txt
# 376  LiDAR_p2p_rsc_chunk_3108_chunk_3109.txt
# 377  LiDAR_p2p_rsc_chunk_3109_chunk_3110.txt
# 378  LiDAR_p2p_rsc_chunk_3110_chunk_3111.txt
# 379  LiDAR_p2p_rsc_chunk_3111_chunk_3112.txt
# 380  LiDAR_p2p_rsc_chunk_3112_chunk_3113.txt
# 381                       aucun fichier .txt
# 382  LiDAR_p2p_rsc_chunk_3114_chunk_3115.txt
# 383  LiDAR_p2p_rsc_chunk_3115_chunk_3116.txt
# 384  LiDAR_p2p_rsc_chunk_3116_chunk_3117.txt
# 385  LiDAR_p2p_rsc_chunk_3117_chunk_3118.txt
# 386                       aucun fichier .txt
# 387                       aucun fichier .txt
# 388  LiDAR_p2p_rsc_chunk_3120_chunk_3121.txt
# 389  LiDAR_p2p_rsc_chunk_3121_chunk_3122.txt
# 390  LiDAR_p2p_rsc_chunk_3122_chunk_3123.txt
# 391  LiDAR_p2p_rsc_chunk_3123_chunk_3124.txt
# 392  LiDAR_p2p_rsc_chunk_3124_chunk_3125.txt
# 393  LiDAR_p2p_rsc_chunk_3125_chunk_3126.txt
# 394                       aucun fichier .txt
# 395  LiDAR_p2p_rsc_chunk_3127_chunk_3128.txt
# 396  LiDAR_p2p_rsc_chunk_3128_chunk_3129.txt
# 397  LiDAR_p2p_rsc_chunk_3129_chunk_3130.txt
# 398  LiDAR_p2p_rsc_chunk_3130_chunk_3131.txt
# 399  LiDAR_p2p_rsc_chunk_3131_chunk_3132.txt
# 400  LiDAR_p2p_rsc_chunk_3132_chunk_3133.txt
# 401  LiDAR_p2p_rsc_chunk_3133_chunk_3134.txt
# 402  LiDAR_p2p_rsc_chunk_3134_chunk_3135.txt
# 403  LiDAR_p2p_rsc_chunk_3135_chunk_3136.txt
# 404  LiDAR_p2p_rsc_chunk_3136_chunk_3137.txt
# 405  LiDAR_p2p_rsc_chunk_3137_chunk_3138.txt
# 406  LiDAR_p2p_rsc_chunk_3138_chunk_3139.txt
# 407  LiDAR_p2p_rsc_chunk_3139_chunk_3140.txt
# 408  LiDAR_p2p_rsc_chunk_3140_chunk_3141.txt
# 409  LiDAR_p2p_rsc_chunk_3141_chunk_3142.txt
# 410  LiDAR_p2p_rsc_chunk_3142_chunk_3143.txt
# 411  LiDAR_p2p_rsc_chunk_3143_chunk_3144.txt
# 412  LiDAR_p2p_rsc_chunk_3144_chunk_3145.txt
# 413  LiDAR_p2p_rsc_chunk_3145_chunk_3146.txt
# 414  LiDAR_p2p_rsc_chunk_3146_chunk_3147.txt
# 415  LiDAR_p2p_rsc_chunk_3147_chunk_3148.txt
# 416  LiDAR_p2p_rsc_chunk_3148_chunk_3149.txt
# 417  LiDAR_p2p_rsc_chunk_3149_chunk_3150.txt
# 418  LiDAR_p2p_rsc_chunk_3150_chunk_3151.txt
# 419  LiDAR_p2p_rsc_chunk_3151_chunk_3152.txt
# 420  LiDAR_p2p_rsc_chunk_3152_chunk_3153.txt
# 421  LiDAR_p2p_rsc_chunk_3153_chunk_3154.txt
# 422  LiDAR_p2p_rsc_chunk_3154_chunk_3155.txt
# 423  LiDAR_p2p_rsc_chunk_3155_chunk_3156.txt
# 424  LiDAR_p2p_rsc_chunk_3156_chunk_3157.txt
# 425  LiDAR_p2p_rsc_chunk_3157_chunk_3158.txt
# 426  LiDAR_p2p_rsc_chunk_3158_chunk_3159.txt
# 427  LiDAR_p2p_rsc_chunk_3159_chunk_3160.txt
# 428  LiDAR_p2p_rsc_chunk_3160_chunk_3161.txt
# 429  LiDAR_p2p_rsc_chunk_3161_chunk_3162.txt
# 430                       aucun fichier .txt
# 431  LiDAR_p2p_rsc_chunk_3163_chunk_3164.txt
# 432                       aucun fichier .txt
# 433                       aucun fichier .txt
# 434                       aucun fichier .txt
# 435                       aucun fichier .txt

# %%
from pathlib import Path

roots = [
    #Path("/media/.../limatch"),
    Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_ODyN/limatch_crossings_v2"),
]
out_file = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/outage_chunks/chunks_VUX_PUCK/hybrid/p2p_hybrid/LiDAR_p2p_all.txt")

with open(out_file, "w") as fout:

    for root in roots:
        files = sorted(root.rglob("LiDAR_p2p_chunk_*.txt"))
        files = [f for f in files if "_rsc_" not in f.name]
        for f in files:
            content = f.read_text()
            if content.strip():
                fout.write(content)
                if not content.endswith("\n"):
                    fout.write("\n")

print(f"Merged → {out_file}")
# Out:
# 30
# Merged → /media/b085164/Elements/CALIB_26_02_25/ODyN_calib/outage_chunks/chunks_VUX_PUCK/hybrid/p2p_hybrid/LiDAR_p2p_all.txt
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np

file = "/media/b085164/Elements/PCD_SAM/village/merged/merged_800_HA_LR.txt"

data = np.loadtxt(file, delimiter=",")

n_points = data.shape[0]

t = data[:, 0]   # colonne 0 = GPS time
tmin = t.min()
tmax = t.max()

print("Number of points:", n_points)
print("tmin:", tmin)
print("tmax:", tmax)
# Out:
# Number of points: 210570172
# tmin: 467364.851373258
# tmax: 467573.346314613
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# --- paths ---
in_path = Path("/media/b085164/Elements/Gobet_ODyN_v1/v4.2_GNSS_outage_limatch_kneighbor1/LiDAR_p2p.txt")      # <-- change to your file
out_path = in_path.with_name(in_path.stem + "_rotvec.txt")

# --- load (CSV with commas) ---
df = pd.read_csv(
    in_path,
    header=None,
    comment="#",
    skip_blank_lines=True
)

# expected columns:
# t_b, t_a, vec_b_x, vec_b_y, vec_b_z, vec_a_x, vec_a_y, vec_a_z
if df.shape[1] < 8:
    raise ValueError(f"Expected at least 8 columns, got {df.shape[1]}")

df = df.iloc[:, :8].copy()
df.columns = ["t_b","t_a","vec_b_x","vec_b_y","vec_b_z","vec_a_x","vec_a_y","vec_a_z"]

R = np.array([[0, 1, 0],
              [1, 0, 0],
              [0, 0,-1]], dtype=float)

# --- apply R to vec_b and vec_a ---
vb = df[["vec_b_x","vec_b_y","vec_b_z"]].to_numpy(float)
va = df[["vec_a_x","vec_a_y","vec_a_z"]].to_numpy(float)

vb_rot = (R @ vb.T).T
va_rot = (R @ va.T).T

df[["vec_b_x","vec_b_y","vec_b_z"]] = vb_rot
df[["vec_a_x","vec_a_y","vec_a_z"]] = va_rot

# --- save ---
df.to_csv(out_path, index=False, header=False, float_format="%.12f")
print("Wrote:", out_path)

# quick sanity check: show first rows
df.head()
# Out:
# Wrote: /media/b085164/Elements/Gobet_ODyN_v1/v4.2_GNSS_outage_limatch_kneighbor1/LiDAR_p2p_rotvec.txt
#              t_b            t_a  vec_b_x  vec_b_y  vec_b_z  vec_a_x  vec_a_y  \
# 0  466562.626260  466560.883635   6.6399  -9.8000  -1.4228    7.303    5.250
# 1  466562.636280  466560.758630   7.0620 -10.0634  -1.2329    7.779    5.941
# 2  466562.641253  466560.888630   6.6870  -9.9051  -1.4968    7.368    5.249
# 3  466562.646229  466561.138493   5.7895  -9.0442  -1.5612    6.270    4.001
# 4  466562.651217  466561.213481   5.4587  -8.7352  -1.6041    5.986    3.667
#
#    vec_a_z
# 0   -1.850
# 1   -1.695
# 2   -1.920
# 3   -1.942
# 4   -1.959
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Get times of each recording

# %%
from pathlib import Path
import os

def quick_time_bounds(txt_path, delimiter=","):
    """
    Read GPS time from first and last line of a large TXT file.
    Assumes:
        column 0 = gps time
    """

    txt_path = Path(txt_path)

    with open(txt_path, "rb") as f:

        # ---- FIRST LINE ----
        first_line = f.readline().decode().strip()
        t0 = float(first_line.split(delimiter)[0])

        # ---- LAST LINE (seek from end) ----
        f.seek(-1024, os.SEEK_END)   # jump near end
        tail = f.readlines()

        # find last non-empty line
        for line in reversed(tail):
            if line.strip():
                last_line = line.decode().strip()
                break

        t1 = float(last_line.split(delimiter)[0])

    return t0, t1
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
merged_dir = Path("/media/b085164/Elements/PCD_SAM/All_pcd/merged")

results = []

for f in sorted(merged_dir.glob("*.txt")):
    try:
        t0, t1 = quick_time_bounds(f)
        results.append((f.name, t0, t1, t1 - t0))
        print(f"{f.name:<40}  [{t0:.3f} → {t1:.3f}]  Δt={t1-t0:.1f}s")
    except Exception as e:
        print(f"{f.name}: FAILED ({e})")
# Out:
# merged_10000_HA_LR.txt                    [467588.721 → 467594.186]  Δt=5.5s
# merged_1000_HA_LR.txt                     [466554.821 → 466860.374]  Δt=305.6s
# merged_11000_HA_LR.txt                    [467604.016 → 467683.827]  Δt=79.8s
# merged_2000_HA_LR.txt                     [466896.472 → 467160.499]  Δt=264.0s
# merged_3000_HA_LR.txt                     [467164.153 → 467180.764]  Δt=16.6s
# merged_4000_HA_LR.txt                     [467181.482 → 467205.529]  Δt=24.0s
# merged_5000_HA_LR.txt                     [467206.034 → 467211.055]  Δt=5.0s
# merged_6000_HA_LR.txt                     [467211.507 → 467226.855]  Δt=15.3s
# merged_7000_HA_LR.txt                     [467227.556 → 467257.452]  Δt=29.9s
# merged_8000_HA_LR.txt                     [467281.138 → 467348.772]  Δt=67.6s
# merged_9000_HA_LR.txt                     [467364.851 → 467573.346]  Δt=208.5s
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Quick GNSS outage

# %%
from pathlib import Path

# =====================================================
# INPUT
# =====================================================

gps_in = Path("/media/b085164/Elements/Gobet_ODyN_v1/v1_base_AB/in/GPS.txt")
gps_out = Path("/media/b085164/Elements/Gobet_ODyN_v1/v6/in/GPS.txt")

# outages = (start_time, duration)
outages = [
    (466930.0, 200.0),
]

delimiter = ","


# =====================================================
# BUILD OUTAGE INTERVALS
# =====================================================

intervals = [(s, s + d) for s, d in outages]

print("Removing GPS data during:")
for a, b in intervals:
    print(f"  [{a:.3f} → {b:.3f}]")


# =====================================================
# FILTER GPS FILE (STREAMING → works for huge files)
# =====================================================

kept = 0
removed = 0

with open(gps_in, "r") as fin, open(gps_out, "w") as fout:

    for line in fin:

        if not line.strip():
            continue

        t = float(line.split(delimiter)[0])

        # check if inside outage
        in_outage = any(a <= t <= b for a, b in intervals)

        if in_outage:
            removed += 1
            continue

        fout.write(line)
        kept += 1


print("\nDone.")
print(f"Kept lines   : {kept}")
print(f"Removed lines: {removed}")
print(f"Output file  : {gps_out}")
# Out:
# Removing GPS data during:
#   [466930.000 → 467130.000]
#
# Done.
# Kept lines   : 3086
# Removed lines: 201
# Output file  : /media/b085164/Elements/Gobet_ODyN_v1/v6/in/GPS.txt
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Split big PCD spatially

# %%
# --- Spatial split into 3 parts (E,N geometry) for TWO huge ASCII point clouds ---
# Assumes each file is a delimited text with at least: [t, E, N, Z, ...]
# You can set which columns are E and N below.

from pathlib import Path
import numpy as np
import pandas as pd
import time

# =========================
# USER CONFIG
# =========================
cloud1 = Path("/media/b085164/Elements/PCD_SAM/longue_ligne/output_Patcher/Flights_1000_2000/Patch_from_scan_1000_with_2000.txt")
cloud2 = Path("/media/b085164/Elements/PCD_SAM/longue_ligne/output_Patcher/Flights_1000_2000/Patch_from_scan_2000_with_1000.txt")

out_dir = Path("/media/b085164/Elements/PCD_SAM/longue_ligne/output_Patcher/output_split")
out_dir.mkdir(parents=True, exist_ok=True)

# delimiter:
# - if whitespace separated: sep = r"\s+" and engine="c"
# - if comma separated: sep = "," and engine="c"
sep = ","          # change to "," if CSV
engine = "c"

# column indices (0-based) for Easting and Northing in your TXT
E_COL = 1
N_COL = 2


CHUNKSIZE = 5_000_000          # try bigger if RAM allows
SAMPLE_TARGET = 600_000        # you can reduce; PCA works well with 200k-1M
SAMPLE_PER_CHUNK = 10_000      # reduce if you want faster first pass

out_sep = "," if sep == "," else " "
float_fmt = "%.6f"

def read_chunks_EN(path: Path):
    for df in pd.read_csv(path, sep=sep, engine=engine, header=None,
                          usecols=[E_COL, N_COL], dtype=np.float64,
                          chunksize=CHUNKSIZE, low_memory=False):
        yield df

def estimate_axis_and_thresholds_from_sample(paths):
    rng = np.random.default_rng(0)
    samples = []
    n_total = 0
    t0 = time.time()

    for p in paths:
        for df in read_chunks_EN(p):
            arr = df.to_numpy(copy=False)
            m = arr.shape[0]
            if m == 0:
                continue
            take = min(SAMPLE_PER_CHUNK, m)
            idx = rng.choice(m, size=take, replace=False)
            samples.append(arr[idx])
            n_total += take
            if n_total >= SAMPLE_TARGET:
                break
        if n_total >= SAMPLE_TARGET:
            break

    X = np.vstack(samples)
    mu = X.mean(axis=0)
    Xc = X - mu
    C = (Xc.T @ Xc) / max(1, (Xc.shape[0] - 1))
    evals, evecs = np.linalg.eigh(C)
    u = evecs[:, np.argmax(evals)]
    u /= np.linalg.norm(u)

    proj = X @ u
    # quantiles on sample => 3 roughly equal parts
    t1, t2 = np.quantile(proj, [1/3, 2/3])

    print(f"[FAST PCA] sample={X.shape[0]:,}, u=[{u[0]:.6f},{u[1]:.6f}], t1={t1:.3f}, t2={t2:.3f} (t={time.time()-t0:.1f}s)")
    return u, float(t1), float(t2)

def split_file_into_3(path_in: Path, u, t1, t2, out_paths):
    outs = [open(p, "w", buffering=1024*1024) for p in out_paths]
    try:
        t0 = time.time()
        n_written = [0,0,0]
        n_total = 0

        for df in pd.read_csv(path_in, sep=sep, engine=engine, header=None,
                              dtype=np.float64, chunksize=CHUNKSIZE, low_memory=False):
            arr = df.to_numpy(copy=False)
            if arr.size == 0:
                continue

            EN = arr[:, [E_COL, N_COL]]
            proj = EN @ u

            m0 = proj < t1
            m1 = (proj >= t1) & (proj < t2)
            m2 = proj >= t2

            if m0.any():
                np.savetxt(outs[0], arr[m0], delimiter=out_sep, fmt=float_fmt); n_written[0]+=int(m0.sum())
            if m1.any():
                np.savetxt(outs[1], arr[m1], delimiter=out_sep, fmt=float_fmt); n_written[1]+=int(m1.sum())
            if m2.any():
                np.savetxt(outs[2], arr[m2], delimiter=out_sep, fmt=float_fmt); n_written[2]+=int(m2.sum())

            n_total += arr.shape[0]
            if n_total % (5*CHUNKSIZE) == 0:
                print(f"  {path_in.name}: processed {n_total:,} rows...")

        print(f"[SPLIT] {path_in.name}: {n_written[0]:,}/{n_written[1]:,}/{n_written[2]:,} (t={time.time()-t0:.1f}s)")
    finally:
        for f in outs: f.close()

u, t1, t2 = estimate_axis_and_thresholds_from_sample([cloud1, cloud2])

c1_out = [out_dir/f"{cloud1.stem}__part1.txt", out_dir/f"{cloud1.stem}__part2.txt", out_dir/f"{cloud1.stem}__part3.txt"]
c2_out = [out_dir/f"{cloud2.stem}__part1.txt", out_dir/f"{cloud2.stem}__part2.txt", out_dir/f"{cloud2.stem}__part3.txt"]

print("\n--- Splitting cloud 1 ---")
split_file_into_3(cloud1, u, t1, t2, c1_out)

print("\n--- Splitting cloud 2 ---")
split_file_into_3(cloud2, u, t1, t2, c2_out)

print("\nDone.")
# Out:
# [FAST PCA] sample=600,000, u=[-0.948999,-0.315278], t1=-2780962.986, t2=-2779498.092 (t=89.3s)
#
# --- Splitting cloud 1 ---
#   Patch_from_scan_1000_with_2000.txt: processed 25,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 50,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 75,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 100,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 125,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 150,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 175,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 200,000,000 rows...
#   Patch_from_scan_1000_with_2000.txt: processed 225,000,000 rows...
# [SPLIT] Patch_from_scan_1000_with_2000.txt: 43,375,613/84,282,195/100,012,993 (t=546.2s)
#
# --- Splitting cloud 2 ---
#   Patch_from_scan_2000_with_1000.txt: processed 25,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 50,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 75,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 100,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 125,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 150,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 175,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 200,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 225,000,000 rows...
#   Patch_from_scan_2000_with_1000.txt: processed 250,000,000 rows...
# [SPLIT] Patch_from_scan_2000_with_1000.txt: 54,302,901/97,457,978/110,147,222 (t=1251.4s)
#
# Done.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from pathlib import Path

# adapte cet import selon où tu exécutes le notebook
from singleBeamMerging import merge_txt_pairs

base_root = Path("/media/b085164/Elements/PCD_SAM/Georef_v6")
scenarios = ["ref", "outage_only"]

for scenario in scenarios:
    scenario_dir = base_root / scenario
    dir_ha = scenario_dir / "HA"
    dir_lr = scenario_dir / "LR"
    out_dir = scenario_dir / "merged"

    print("\n" + "=" * 70)
    print(f"[MERGING SCENARIO] {scenario}")
    print(f"HA dir   : {dir_ha}")
    print(f"LR dir   : {dir_lr}")
    print(f"OUT dir  : {out_dir}")
    print("=" * 70)

    merge_txt_pairs(
        dir_a=dir_ha,
        dir_b=dir_lr,
        out_dir=out_dir,
        delimiter=",",
        skiprows=0,
        sort_by_time=True,
        out_prefix="merged_",
        out_suffix="_HA_LR",
    )

print("\n[DONE] ref + outage_only merged.")
# Out:
# ======================================================================
# [MERGING SCENARIO] ref
# HA dir   : /media/b085164/Elements/PCD_SAM/Georef_v6/ref/HA
# LR dir   : /media/b085164/Elements/PCD_SAM/Georef_v6/ref/LR
# OUT dir  : /media/b085164/Elements/PCD_SAM/Georef_v6/ref/merged
# ======================================================================
#
#  [Merging] files /media/b085164/Elements/PCD_SAM/Georef_v6/ref/HA/250220_094117_VUX-HA1_pcd.txt and /media/b085164/Elements/PCD_SAM/Georef_v6/ref/LR/250220_094117_VUX1-LR_pcd.txt
# 250220_094117_VUX-HA1_pcd.txt + 250220_094117_VUX1-LR_pcd.txt -> merged_94117_HA_LR.txt (140986168 + 120925420 rows)
#
# --- Summary ---
# [Merging] Pairs found: 1 | Merged: 1
# [Merging] Output dir: /media/b085164/Elements/PCD_SAM/Georef_v6/ref/merged
#
# ======================================================================
# [MERGING SCENARIO] outage_only
# HA dir   : /media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/HA
# LR dir   : /media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/LR
# OUT dir  : /media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/merged
# ======================================================================
#
#  [Merging] files /media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/HA/250220_094117_VUX-HA1_pcd.txt and /media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/LR/250220_094117_VUX1-LR_pcd.txt
# 250220_094117_VUX-HA1_pcd.txt + 250220_094117_VUX1-LR_pcd.txt -> merged_94117_HA_LR.txt (140986148 + 120925407 rows)
#
# --- Summary ---
# [Merging] Pairs found: 1 | Merged: 1
# [Merging] Output dir: /media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/merged
#
# [DONE] ref + outage_only merged.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from pathlib import Path
from tqdm import tqdm

# -------------------------------------------------------------------
# ROOT FOLDER TO SCAN
# -------------------------------------------------------------------
root_folder = Path("/media/b085164/Elements/PCD_SAM/Georef_v6/")

# -------------------------------------------------------------------
# FUNCTION: fast line counting (streaming)
# -------------------------------------------------------------------
def count_lines_fast(file_path, chunk_size=1024*1024*16):
    count = 0
    with open(file_path, "rb") as f:
        while chunk := f.read(chunk_size):
            count += chunk.count(b"\n")
    return count

# -------------------------------------------------------------------
# FIND ALL TXT FILES
# -------------------------------------------------------------------
txt_files = sorted(root_folder.rglob("*.txt"))

print(f"Found {len(txt_files)} txt files\n")

results = []

for f in tqdm(txt_files, desc="Counting lines"):
    try:
        n = count_lines_fast(f)
        results.append((str(f), n))
    except Exception as e:
        results.append((str(f), f"ERROR: {e}"))

# -------------------------------------------------------------------
# PRINT RESULTS
# -------------------------------------------------------------------
print("\n================ LINE COUNTS ================\n")

for path, n in results:
    print(f"{n:>15}  |  {path}")
# Out:
# Found 4 txt files
# Counting lines: 100%|██████████| 4/4 [16:17<00:00, 244.38s/it]
# ================ LINE COUNTS ================
#
# Found 4 txt files
# Counting lines: 100%|██████████| 4/4 [19:00<00:00, 285.16s/it]
# ================ LINE COUNTS ================
#
#       261911575  |  /media/b085164/Elements/PCD_SAM/Georef_v6/limatch_chunk2chunk/merged/merged_94117_HA_LR.txt
#       261911762  |  /media/b085164/Elements/PCD_SAM/Georef_v6/limatch_scan2scan/merged/merged_94117_HA_LR.txt
#       261911555  |  /media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/merged/merged_94117_HA_LR.txt
#       261911588  |  /media/b085164/Elements/PCD_SAM/Georef_v6/ref/merged/merged_94117_HA_LR.txt
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from pathlib import Path

def first_last_valid_line(path):
    path = Path(path)

    # ---- first non-empty line
    with open(path, "r", errors="ignore") as f:
        first = None
        for line in f:
            line = line.strip()
            if line:
                first = line
                break

    # ---- last non-empty line
    with open(path, "rb") as f:
        f.seek(0, 2)
        pos = f.tell() - 1
        last = None
        buffer = b""

        while pos > 0:
            f.seek(pos)
            char = f.read(1)

            if char == b"\n":
                line = buffer[::-1].decode("utf-8", errors="ignore").strip()
                if line:
                    last = line
                    break
                buffer = b""
            else:
                buffer += char

            pos -= 1

        if last is None:
            last = buffer[::-1].decode("utf-8", errors="ignore").strip()

    return first, last


def parse_time(line, delim=",", time_col=0):
    parts = [p.strip() for p in line.split(delim)]
    return float(parts[time_col])


ref_txt = "/media/b085164/Elements/PCD_SAM/Georef_v6/ref/merged/merged_94117_HA_LR.txt"
tgt_txt = "/media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/merged/merged_94117_HA_LR.txt"

for label, path in [("REF", ref_txt), ("TGT", tgt_txt)]:
    first, last = first_last_valid_line(path)

    t0 = parse_time(first)
    t1 = parse_time(last)

    print("================================")
    print(label)
    print("first line:", first[:120])
    print("last  line:", last[:120])
    print("time range:", t0, "->", t1)
    print()
# Out:
# ================================
# REF
# first line: 466896.4715145370,2546313.0499999998,1158624.5959999999,875.2490000000,-16.2140000000,-11.5380000000,2.3540000000
# last  line: 467160.4990706540,2542670.3380000000,1157328.1259999999,906.4630000000,11.0020000000,-12.6730000000,1.9690000000
# time range: 466896.471514537 -> 467160.499070654
#
# ================================
# TGT
# first line: 466896.4715145370,2546313.0510000000,1158624.5959999999,875.2490000000,-16.2140000000,-11.5380000000,2.3540000000
# last  line: 467160.4990706540,2542670.3369999998,1157328.1270000001,906.4650000000,11.0020000000,-12.6730000000,1.9690000000
# time range: 466896.471514537 -> 467160.499070654
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from pathlib import Path

ref_txt = Path("/media/b085164/Elements/PCD_SAM/Georef_v6/ref/merged/merged_94117_HA_LR.txt")
tgt_txt = Path("/media/b085164/Elements/PCD_SAM/Georef_v6/outage_only/merged/merged_94117_HA_LR.txt")

def first_token(line, delim=","):
    return line.split(delim, 1)[0].strip()

def compare_times_streaming(ref_path, tgt_path, delim=",", max_report=10):
    n = 0
    diffs = []

    with open(ref_path, "r", errors="ignore") as f_ref, open(tgt_path, "r", errors="ignore") as f_tgt:
        while True:
            lref = f_ref.readline()
            ltgt = f_tgt.readline()

            if not lref and not ltgt:
                break

            n += 1

            # cas fin de fichier asymétrique
            if not lref:
                diffs.append((n, "REF_EOF", None, first_token(ltgt, delim)))
                break
            if not ltgt:
                diffs.append((n, "TGT_EOF", first_token(lref, delim), None))
                break

            lref = lref.strip()
            ltgt = ltgt.strip()

            if not lref or not ltgt:
                diffs.append((n, "EMPTY_LINE", lref, ltgt))
                if len(diffs) >= max_report:
                    break
                continue

            tref = first_token(lref, delim)
            ttgt = first_token(ltgt, delim)

            if tref != ttgt:
                diffs.append((n, "TIME_MISMATCH", tref, ttgt))
                if len(diffs) >= max_report:
                    break

    return diffs, n

diffs, n_checked = compare_times_streaming(ref_txt, tgt_txt)

print(f"Lines checked: {n_checked}")
if not diffs:
    print("No timestamp mismatch found on aligned line-by-line comparison.")
else:
    print("\nFirst mismatches found:\n")
    for d in diffs:
        print(d)
# Out:
# Lines checked: 62209469
#
# First mismatches found:
#
# (62209460, 'TIME_MISMATCH', '466958.6020512580', '466958.6020506240')
# (62209461, 'TIME_MISMATCH', '466958.6020521460', '466958.6020512580')
# (62209462, 'TIME_MISMATCH', '466958.6020531140', '466958.6020521460')
# (62209463, 'TIME_MISMATCH', '466958.6020541680', '466958.6020531140')
# (62209464, 'TIME_MISMATCH', '466958.6020550930', '466958.6020541680')
# (62209465, 'TIME_MISMATCH', '466958.6020561050', '466958.6020550930')
# (62209466, 'TIME_MISMATCH', '466958.6020569930', '466958.6020561050')
# (62209467, 'TIME_MISMATCH', '466958.6020579610', '466958.6020569930')
# (62209468, 'TIME_MISMATCH', '466958.6020590140', '466958.6020579610')
# (62209469, 'TIME_MISMATCH', '466958.6020599430', '466958.6020590140')
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Comparaing SBET trajectories (Julien & RD) CALIB

# %%
# ============================================================
# Compare two SBET files on common time interval
# - interactive Plotly figures
# - position and attitude metrics
# - handles different durations (overlap only)
# ============================================================

from pathlib import Path
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from scipy.spatial.transform import Rotation as R, Slerp
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# ------------------------------------------------------------
# USER INPUT
# ------------------------------------------------------------
sbet_ref = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/base_v0/in/reference.out")
sbet_cmp = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/base_v0/out/ODyN_GNSS_INS.out")

# If your SBET time is GPS seconds-of-week and one file has small edge mismatch,
# you can optionally trim a tiny safety margin:
time_margin_s = 0.0

# ------------------------------------------------------------
# Standard Applanix SBET dtype (17 float64 values per record)
# ------------------------------------------------------------
SBET_DTYPE = np.dtype([
    ("time",        np.float64),
    ("lat",         np.float64),   # radians
    ("lon",         np.float64),   # radians
    ("alt",         np.float64),   # meters
    ("vx",          np.float64),
    ("vy",          np.float64),
    ("vz",          np.float64),
    ("roll",        np.float64),   # radians
    ("pitch",       np.float64),   # radians
    ("heading",     np.float64),   # radians
    ("wander",      np.float64),
    ("ax",          np.float64),
    ("ay",          np.float64),
    ("az",          np.float64),
    ("wx",          np.float64),
    ("wy",          np.float64),
    ("wz",          np.float64),
])

# ------------------------------------------------------------
# Helpers
# ------------------------------------------------------------
def load_sbet(path: Path) -> pd.DataFrame:
    arr = np.fromfile(path, dtype=SBET_DTYPE)
    if arr.size == 0:
        raise ValueError(f"Empty SBET or unreadable file: {path}")
    df = pd.DataFrame(arr)
    return df

def wrap_angle_rad(a):
    """Wrap angle to [-pi, pi]."""
    return (a + np.pi) % (2 * np.pi) - np.pi

def rad2deg(a):
    return np.rad2deg(a)

def geodetic_to_local_enu(lat, lon, h, lat0, lon0, h0):
    """
    Approximate local ENU from geodetic coordinates.
    Good enough for trajectory comparison over local extents.
    lat/lon in radians, h in meters.
    """
    # WGS84
    a = 6378137.0
    f = 1 / 298.257223563
    e2 = f * (2 - f)

    def geodetic_to_ecef(lat, lon, h):
        sin_lat = np.sin(lat)
        cos_lat = np.cos(lat)
        sin_lon = np.sin(lon)
        cos_lon = np.cos(lon)
        N = a / np.sqrt(1 - e2 * sin_lat**2)
        X = (N + h) * cos_lat * cos_lon
        Y = (N + h) * cos_lat * sin_lon
        Z = (N * (1 - e2) + h) * sin_lat
        return X, Y, Z

    X, Y, Z = geodetic_to_ecef(lat, lon, h)
    X0, Y0, Z0 = geodetic_to_ecef(lat0, lon0, h0)

    dX = X - X0
    dY = Y - Y0
    dZ = Z - Z0

    sin_lat0 = np.sin(lat0)
    cos_lat0 = np.cos(lat0)
    sin_lon0 = np.sin(lon0)
    cos_lon0 = np.cos(lon0)

    t = np.array([
        [-sin_lon0,              cos_lon0,             0],
        [-sin_lat0*cos_lon0, -sin_lat0*sin_lon0, cos_lat0],
        [ cos_lat0*cos_lon0,  cos_lat0*sin_lon0, sin_lat0],
    ])

    xyz = np.vstack([dX, dY, dZ])
    enu = t @ xyz
    return enu[0], enu[1], enu[2]

def make_rotation_from_rph(roll, pitch, heading):
    """
    Build scipy Rotation from roll/pitch/heading.
    Convention chosen here: intrinsic XYZ on body angles, using
    roll, pitch, heading as x, y, z Euler sequence.
    If your convention is different, adapt here.
    """
    return R.from_euler("xyz", np.column_stack([roll, pitch, heading]), degrees=False)

def summary_stats(x):
    return {
        "mean": float(np.mean(x)),
        "median": float(np.median(x)),
        "rms": float(np.sqrt(np.mean(x**2))),
        "max_abs": float(np.max(np.abs(x))),
        "p95_abs": float(np.percentile(np.abs(x), 95)),
    }

# ------------------------------------------------------------
# Load
# ------------------------------------------------------------
df_ref = load_sbet(sbet_ref)
df_cmp = load_sbet(sbet_cmp)

print("Loaded:")
print(f"  RD: {sbet_ref} -> {len(df_ref):,} records")
print(f"  Julien: {sbet_cmp} -> {len(df_cmp):,} records")

print("\nTime spans:")
print(f"  RD: [{df_ref.time.min():.4f}, {df_ref.time.max():.4f}]")
print(f"  Julien: [{df_cmp.time.min():.4f}, {df_cmp.time.max():.4f}]")

# ------------------------------------------------------------
# Restrict to common overlap
# ------------------------------------------------------------
t0 = max(df_ref.time.min(), df_cmp.time.min()) + time_margin_s
t1 = min(df_ref.time.max(), df_cmp.time.max()) - time_margin_s

if t1 <= t0:
    raise ValueError(
        f"No common time overlap.\n"
        f"RD: [{df_ref.time.min():.4f}, {df_ref.time.max():.4f}]\n"
        f"Julien: [{df_cmp.time.min():.4f}, {df_cmp.time.max():.4f}]"
    )

df_ref_ov = df_ref[(df_ref.time >= t0) & (df_ref.time <= t1)].copy()
df_cmp_ov = df_cmp[(df_cmp.time >= t0) & (df_cmp.time <= t1)].copy()

print("\nCommon overlap:")
print(f"  [{t0:.4f}, {t1:.4f}]")
print(f"  RD overlap samples: {len(df_ref_ov):,}")
print(f"  Julien overlap samples: {len(df_cmp_ov):,}")

t = df_ref_ov.time.to_numpy()

# ------------------------------------------------------------
# Interpolate CMP position onto REF times
# ------------------------------------------------------------
interp_lat = interp1d(df_cmp_ov.time, df_cmp_ov.lat, kind="linear", bounds_error=True)
interp_lon = interp1d(df_cmp_ov.time, df_cmp_ov.lon, kind="linear", bounds_error=True)
interp_alt = interp1d(df_cmp_ov.time, df_cmp_ov.alt, kind="linear", bounds_error=True)

lat_ref = df_ref_ov.lat.to_numpy()
lon_ref = df_ref_ov.lon.to_numpy()
alt_ref = df_ref_ov.alt.to_numpy()

lat_cmp_i = interp_lat(t)
lon_cmp_i = interp_lon(t)
alt_cmp_i = interp_alt(t)

# ------------------------------------------------------------
# Local ENU trajectories (same origin = first REF overlap sample)
# ------------------------------------------------------------
lat0 = lat_ref[0]
lon0 = lon_ref[0]
h0 = alt_ref[0]

E_ref, N_ref, U_ref = geodetic_to_local_enu(lat_ref, lon_ref, alt_ref, lat0, lon0, h0)
E_cmp, N_cmp, U_cmp = geodetic_to_local_enu(lat_cmp_i, lon_cmp_i, alt_cmp_i, lat0, lon0, h0)

dE = E_cmp - E_ref
dN = N_cmp - N_ref
dU = U_cmp - U_ref
dh = np.sqrt(dE**2 + dN**2)
d3 = np.sqrt(dE**2 + dN**2 + dU**2)

# ------------------------------------------------------------
# Interpolate CMP attitude onto REF times using SLERP
# ------------------------------------------------------------
rot_ref = make_rotation_from_rph(
    df_ref_ov.roll.to_numpy(),
    df_ref_ov.pitch.to_numpy(),
    df_ref_ov.heading.to_numpy(),
)

rot_cmp = make_rotation_from_rph(
    df_cmp_ov.roll.to_numpy(),
    df_cmp_ov.pitch.to_numpy(),
    df_cmp_ov.heading.to_numpy(),
)

slerp = Slerp(df_cmp_ov.time.to_numpy(), rot_cmp)
rot_cmp_i = slerp(t)

rot_rel = rot_ref.inv() * rot_cmp_i
rotvec_rel = rot_rel.as_rotvec()
angle_total_deg = np.rad2deg(np.linalg.norm(rotvec_rel, axis=1))

roll_ref = df_ref_ov.roll.to_numpy()
pitch_ref = df_ref_ov.pitch.to_numpy()
heading_ref = df_ref_ov.heading.to_numpy()

eul_cmp_i = rot_cmp_i.as_euler("xyz", degrees=False)
roll_cmp_i = eul_cmp_i[:, 0]
pitch_cmp_i = eul_cmp_i[:, 1]
heading_cmp_i = eul_cmp_i[:, 2]

droll_deg = rad2deg(wrap_angle_rad(roll_cmp_i - roll_ref))
dpitch_deg = rad2deg(wrap_angle_rad(pitch_cmp_i - pitch_ref))
dheading_deg = rad2deg(wrap_angle_rad(heading_cmp_i - heading_ref))

# ------------------------------------------------------------
# Metrics
# ------------------------------------------------------------
metrics = {
    "horizontal_m": summary_stats(dh),
    "vertical_m": summary_stats(dU),
    "position_3d_m": summary_stats(d3),
    "roll_deg": summary_stats(droll_deg),
    "pitch_deg": summary_stats(dpitch_deg),
    "heading_deg": summary_stats(dheading_deg),
    "attitude_total_deg": summary_stats(angle_total_deg),
}

metrics_df = pd.DataFrame(metrics).T
display(metrics_df)

# ------------------------------------------------------------
# Plot 1: simple position differences
# ------------------------------------------------------------
fig_pos = make_subplots(
    rows=5, cols=1, shared_xaxes=True, vertical_spacing=0.04,
    subplot_titles=("dE [m]", "dN [m]", "dU [m]", "Horizontal [m]", "3D [m]")
)

fig_pos.add_trace(go.Scattergl(x=t, y=dE, name="dE"), row=1, col=1)
fig_pos.add_trace(go.Scattergl(x=t, y=dN, name="dN"), row=2, col=1)
fig_pos.add_trace(go.Scattergl(x=t, y=dU, name="dU"), row=3, col=1)
fig_pos.add_trace(go.Scattergl(x=t, y=dh, name="Horizontal"), row=4, col=1)
fig_pos.add_trace(go.Scattergl(x=t, y=d3, name="3D"), row=5, col=1)

fig_pos.update_layout(
    title="SBET comparison - Position differences",
    height=1100,
)
fig_pos.update_xaxes(title_text="Time [s]", row=5, col=1)
fig_pos.show()

# ------------------------------------------------------------
# Plot 2: simple attitude differences
# ------------------------------------------------------------
fig_att = make_subplots(
    rows=4, cols=1, shared_xaxes=True, vertical_spacing=0.04,
    subplot_titles=("dRoll [deg]", "dPitch [deg]", "dHeading [deg]", "Total relative angle [deg]")
)

fig_att.add_trace(go.Scattergl(x=t, y=droll_deg, name="dRoll"), row=1, col=1)
fig_att.add_trace(go.Scattergl(x=t, y=dpitch_deg, name="dPitch"), row=2, col=1)
fig_att.add_trace(go.Scattergl(x=t, y=dheading_deg, name="dHeading"), row=3, col=1)
fig_att.add_trace(go.Scattergl(x=t, y=angle_total_deg, name="Total attitude angle"), row=4, col=1)

fig_att.update_layout(
    title="SBET comparison - Attitude differences",
    height=950,
)
fig_att.update_xaxes(title_text="Time [s]", row=4, col=1)
fig_att.show()

print("\nQuick summary:")
print(f"  Horizontal RMS:   {metrics['horizontal_m']['rms']:.4f} m")
print(f"  Vertical RMS:     {metrics['vertical_m']['rms']:.4f} m")
print(f"  3D RMS:           {metrics['position_3d_m']['rms']:.4f} m")
print(f"  Roll RMS:         {metrics['roll_deg']['rms']:.6f} deg")
print(f"  Pitch RMS:        {metrics['pitch_deg']['rms']:.6f} deg")
print(f"  Heading RMS:      {metrics['heading_deg']['rms']:.6f} deg")
print(f"  Total angle RMS:  {metrics['attitude_total_deg']['rms']:.6f} deg")
# Out:
# Loaded:
#   RD: /media/b085164/Elements/CALIB_26_02_25/ODyN_calib/base_v0/in/reference.out -> 556,368 records
#   Julien: /media/b085164/Elements/CALIB_26_02_25/ODyN_calib/base_v0/out/ODyN_GNSS_INS.out -> 39,900 records
#
# Time spans:
#   RD: [304508.0000, 307276.0000]
#   Julien: [304790.0043, 306784.9543]
#
# Common overlap:
#   [304790.0043, 306784.9543]
#   RD overlap samples: 400,985
#   Julien overlap samples: 39,900
#                         mean    median       rms   max_abs   p95_abs
# horizontal_m        0.014672  0.007558  0.031136  0.200687  0.070174
# vertical_m          0.005353  0.000105  0.030536  0.216460  0.038342
# position_3d_m       0.020050  0.009692  0.043611  0.294907  0.081036
# roll_deg            0.000002 -0.000057  0.011022  0.204479  0.022303
# pitch_deg           0.000690  0.000864  0.013718  0.144439  0.028859
# heading_deg        -0.001736 -0.002872  0.022901  0.145510  0.048121
# attitude_total_deg  0.023619  0.019797  0.028866  0.229297  0.055177

# %% [markdown]
# ### simple merge .txt

# %%
from pathlib import Path
import numpy as np

# ------------------------------------------------------------
# USER INPUT
# ------------------------------------------------------------
file1 = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/p2p/LiDAR_p2p_1.txt")
file2 = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/p2p/LiDAR_p2p_2.txt")
out_file = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/p2p/LiDAR_p2p.txt")

delimiter = ","
skiprows = 0
sort_by_first_column = True

# ------------------------------------------------------------
# Load
# ------------------------------------------------------------
a = np.loadtxt(file1, delimiter=delimiter, skiprows=skiprows)
b = np.loadtxt(file2, delimiter=delimiter, skiprows=skiprows)

if a.ndim == 1:
    a = a.reshape(1, -1)
if b.ndim == 1:
    b = b.reshape(1, -1)

if a.shape[1] != b.shape[1]:
    raise ValueError(
        f"Column mismatch: {file1.name} has {a.shape[1]} cols, "
        f"{file2.name} has {b.shape[1]} cols."
    )

# ------------------------------------------------------------
# Merge
# ------------------------------------------------------------
merged = np.vstack([a, b])

if sort_by_first_column:
    merged = merged[np.argsort(merged[:, 0])]

# ------------------------------------------------------------
# Save
# ------------------------------------------------------------
out_file.parent.mkdir(parents=True, exist_ok=True)
np.savetxt(out_file, merged, delimiter=delimiter, fmt="%.10f")

print(f"Merged file saved to: {out_file}")
print(f"Rows: {len(a)} + {len(b)} = {len(merged)}")
# Out:
# Merged file saved to: /media/b085164/Elements/CALIB_26_02_25/ODyN_calib/p2p/LiDAR_p2p.txt
# Rows: 1481 + 5551 = 7032
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## GPS quality (coupure et plot sigmas)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# ── Chargement ────────────────────────────────────────────────────────────
df = pd.read_csv(
    "/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/AIRINS/base/in/GPS.txt",
    header=None,
    names=["time", "lat", "lon", "alt", "sig_E", "sig_N", "sig_H"]
)
df = df.sort_values("time").reset_index(drop=True)

# ── Quality thresholds (same for E / N / H) ──────────────────────────────
THR_GOOD = 0.03   # 3 cm
THR_WARN = 0.10   # 10 cm

# ── Quality flag per epoch ────────────────────────────────────────────────
def quality(row):
    vals = [row.sig_E, row.sig_N, row.sig_H]
    if all(v <= THR_GOOD for v in vals):
        return "good"
    elif all(v <= THR_WARN for v in vals):
        return "warn"
    return "bad"

df["quality"] = df.apply(quality, axis=1)

# ── Continuous segments + gaps ────────────────────────────────────────────
dt = df["time"].diff()
nominal_dt = dt.mode()[0]
threshold = dt.mode()[0] * 1.5
df["seg_id"] = (dt > threshold).cumsum()

segments, gaps = [], []
for sid, grp in df.groupby("seg_id"):
    dominant = grp["quality"].mode()[0]
    segments.append({
        "seg": sid + 1,
        "t_start": grp["time"].iloc[0],
        "t_end": grp["time"].iloc[-1],
        "duration": grp["time"].iloc[-1] - grp["time"].iloc[0],
        "n_epochs": len(grp),
        "quality": dominant,
        "sig_E_mean": grp["sig_E"].mean(),
        "sig_N_mean": grp["sig_N"].mean(),
        "sig_H_mean": grp["sig_H"].mean(),
    })

gap_idx = df.index[dt > threshold]
for i in gap_idx:
    gaps.append({
        "t_start": df["time"].iloc[i - 1],
        "t_end": df["time"].iloc[i],
        "dur": df["time"].iloc[i] - df["time"].iloc[i - 1],
    })

seg_df = pd.DataFrame(segments)
gap_df = pd.DataFrame(gaps) if gaps else pd.DataFrame(columns=["t_start", "t_end", "dur"])

# ── Plot ──────────────────────────────────────────────────────────────────
color_map = {"good": "#1D9E75", "warn": "#BA7517", "bad": "#E24B4A"}
cols = ["sig_E", "sig_N", "sig_H"]
labels = ["σ East (m)", "σ North (m)", "σ Up (m)"]

fig, axes = plt.subplots(3, 1, figsize=(14, 8), sharex=True)
fig.suptitle("GNSS quality during the acquisition — σ East / North / Up (log scale)", fontsize=13)

for ax, col, label in zip(axes, cols, labels):
    for _, s in seg_df.iterrows():
        ax.axvspan(
            s.t_start, s.t_end,
            alpha=0.07, color=color_map[s.quality], zorder=1
        )

    for _, g in gap_df.iterrows():
        ax.axvspan(
            g.t_start, g.t_end,
            alpha=0.40, color="#E24B4A", hatch="///",
            edgecolor="#A32D2D", linewidth=0, zorder=2
        )

    colors = [color_map[q] for q in df["quality"]]
    ax.scatter(df["time"], df[col], c=colors, s=8, zorder=4)

    ax.axhline(THR_GOOD, color="#1D9E75", lw=0.8, ls="--", zorder=3)
    ax.axhline(THR_WARN, color="#BA7517", lw=0.8, ls="--", zorder=3)

    ax.set_yscale("log")   
    ax.set_ylabel(label, fontsize=12)
    ax.grid(True, which="both", alpha=0.25)
    ax.tick_params(axis='both', labelsize=10)

axes[-1].set_xlabel("GPS time (s)", fontsize=12)
#axes[-1].tick_params(axis='x', labelsize=10)

patches = [
    mpatches.Patch(
        color="#1D9E75", alpha=0.6,
        label=f"Good (all σ ≤ {THR_GOOD*100:.0f} cm)"
    ),
    mpatches.Patch(
        color="#BA7517", alpha=0.6,
        label=f"Fair (all σ ≤ {THR_WARN*100:.0f} cm)"
    ),
    mpatches.Patch(color="#E24B4A", alpha=0.6, label="Poor"),
    mpatches.Patch(
        facecolor="#E24B4A", alpha=0.4, hatch="///",
        edgecolor="#A32D2D", label="GPS gap"
    ),
]
axes[0].legend(handles=patches, fontsize=12, loc="upper left", ncol=2)

plt.tight_layout()
plt.savefig("/home/b085164/PDM_Romain_Defferrard/images/gps_quality_CALIB.png", dpi=400, bbox_inches="tight")
plt.show()

# ── Gap summary ───────────────────────────────────────────────────────────
print(f"\n{len(gap_df)} gap(s) detected — nominal rate: {nominal_dt:.1f} s")
for i, (_, g) in enumerate(gap_df.iterrows(), 1):
    h, m, s = int(g.dur)//3600, (int(g.dur)%3600)//60, int(g.dur)%60
    print(f"  #{i}  {g.t_start:.1f} → {g.t_end:.1f}   Δt = {g.dur:.1f} s  ({h:02d}h{m:02d}m{s:02d}s)")
# Out:
# /tmp/ipykernel_1078059/485023751.py:77: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.axvspan(
# 3 gap(s) detected — nominal rate: 1.0 s
#   #1  305024.0 → 305030.0   Δt = 6.0 s  (00h00m06s)
#   #2  306131.0 → 306139.0   Δt = 8.0 s  (00h00m08s)
#   #3  306248.0 → 306254.0   Δt = 6.0 s  (00h00m06s)

# %%
# Out:
# /tmp/ipykernel_313212/4293906530.py:72: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   ax.axvspan(g.t_start, g.t_end,
# 3 gap(s) detected — nominal rate: 1.0 s
#   #1  305024.0 → 305030.0   Δt = 6.0 s  (00h00m06s)
#   #2  306131.0 → 306139.0   Δt = 8.0 s  (00h00m08s)
#   #3  306248.0 → 306254.0   Δt = 6.0 s  (00h00m06s)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Merge et classif des trois scanner

# %% [markdown]
# ### Fait:
#
# - lit les nuages VUX déjà merged d'un dossier
# - lit les nuages PUCK d'un autre dossier
# - utilise les `gps_time` pour répartir les points puck dans le bon nuages VUX
# - Règle spéciale: les point du PUCK entre deux nuages VUX vont dans le nuage suivant
# - Ajoute un extrabyte `scanner_src`:
#     - 2 = point venant des VUX
#     - 1 = point venant du PUCK

# %% [markdown]
# ## Fichier LiDAR_p2p problématique

# %%
import os
import random

input_file = "/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/Outage_1_305120_305700/S2S/in/chunks/full/LiDAR_p2p.txt"

k = 540000
output_dir = f"/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/Outage_1_305120_305700/S2S/in/chunks/full/random_{k}"
output_file = os.path.join(output_dir, "LiDAR_p2p.txt")

# --- Create directory ---
os.makedirs(output_dir, exist_ok=True)

# --- Optional: fix seed pour reproductibilité ---
random.seed(42)

reservoir = []

# --- Sampling ---
with open(input_file, "r") as f:
    for i, line in enumerate(f):
        if i < k:
            reservoir.append(line)
        else:
            j = random.randint(0, i)
            if j < k:
                reservoir[j] = line

print(f"Sampling terminé : {len(reservoir)} lignes")

# --- Sort sur la première colonne ---
def get_first_col(line):
    return float(line.split()[0].rstrip(","))

reservoir.sort(key=get_first_col)

# --- Write ---
with open(output_file, "w") as f:
    f.writelines(reservoir)

print(f"Fichier écrit dans : {output_file}")
# Out:
# Sampling terminé : 540000 lignes
# Fichier écrit dans : /media/b085164/Elements/CALIB_26_02_25/ODyN_calib/Outage_1_305120_305700/S2S/in/chunks/full/random_540000/LiDAR_p2p.txt

# %% [markdown]
# ## Success rate des méthodes

# %%
import os

# =========================
# CONFIG
# =========================

limatch_paths = [
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/limatch_F2B_v2",
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/limatch_F2B_v2_crossings",
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_3/limatch_F2B_v2",
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_3/limatch_F2B_v2_crossings",
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_1/limatch_500x500",
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_1/limatch_crossings",
    "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_3/APX/limatch_F2B", 
    "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/limatch_F2B", 
]

s2s_paths = [
    # # outage 1
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_1/s2s_chunks/pairs_1/Flights_1_2/Patch_from_scan_1_with_2_vs_Patch_from_scan_2_with_1/limatch",
    
    # # outage 2
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/s2s_chunks/limatch",
    
    # # outage 3
    # "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_3/s2s_chunks",
]

# =========================
# UTILS
# =========================

def is_non_empty_dir(path):
    for f in os.listdir(path):
        full = os.path.join(path, f)
        if os.path.isfile(full) and os.path.getsize(full) > 0:
            return True
    return False

# =========================
# LIMATCH (merged/chunks)
# =========================

def compute_limatch_sr(base_dir):
    total, success = 0, 0

    for merged in os.listdir(base_dir):
        merged_path = os.path.join(base_dir, merged)
        if not os.path.isdir(merged_path):
            continue

        for chunk in os.listdir(merged_path):
            chunk_path = os.path.join(merged_path, chunk)
            cor_path = os.path.join(chunk_path, "cor_outputs")

            if not os.path.isdir(cor_path):
                continue

            total += 1
            if is_non_empty_dir(cor_path):
                success += 1

    return success, total

# =========================
# S2S (chunk direct)
# =========================

def compute_s2s_sr_nested(base_dir):
    total, success = 0, 0

    for root, dirs, files in os.walk(base_dir):
        # On cherche directement les dossiers "cor_outputs"
        if os.path.basename(root) == "cor_outputs":
            
            total += 1

            if is_non_empty_dir(root):
                success += 1

    return success, total

# =========================
# RUN
# =========================

print("===== LIMATCH =====")
limatch_total = 0
limatch_success = 0

for path in limatch_paths:
    s, t = compute_limatch_sr(path)
    limatch_total += t
    limatch_success += s
    print(f"{path} -> {s}/{t} ({s/t if t>0 else 0:.3f})")

print("\nGLOBAL LIMATCH SR :", limatch_success, "/", limatch_total, "->", 
      f"{limatch_success/limatch_total:.4f}" if limatch_total>0 else "N/A")


print("\n===== S2S =====")
s2s_total = 0
s2s_success = 0

for path in s2s_paths:
    s, t = compute_s2s_sr_nested(path)
    s2s_total += t
    s2s_success += s
    print(f"{path} -> {s}/{t} ({s/t if t>0 else 0:.3f})")

print("\nGLOBAL S2S SR :", s2s_success, "/", s2s_total, "->", 
      f"{s2s_success/s2s_total:.4f}" if s2s_total>0 else "N/A")
# Out:
# ===== LIMATCH =====
# /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_3/APX/limatch_F2B -> 135/270 (0.500)
# /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/limatch_F2B -> 80/259 (0.309)
#
# GLOBAL LIMATCH SR : 215 / 529 -> 0.4064
#
# ===== S2S =====
#
# GLOBAL S2S SR : 0 / 0 -> N/A

# %%
import laspy as lp
las = lp.read("/media/b085164/LaCie/2026spring_RD/ECCR/georef_ALL_zone_3_outage/merged/ALL/merged_1000_VUX_PUCK.las")
print(f"header min gps_time : {las.header.mins}")
print(f"header max gps_time : {las.header.maxs}")
print(f"réel min gps_time   : {las.gps_time.min():.3f}")
print(f"réel max gps_time   : {las.gps_time.max():.3f}")
# Out:
# header min gps_time : [2.53315411e+06 1.15506819e+06 4.57270000e+02]
# header max gps_time : [2.53331459e+06 1.15518327e+06 4.83854000e+02]
# réel min gps_time   : 315632.000
# réel max gps_time   : 315662.282

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import folium

# ------------------------------------------------------------
# INPUT
# ------------------------------------------------------------
manifest_path = "/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/merged/ALL/merged_manifest.csv"
traj_path     = "/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/combined_w_traj_f2b/combined/in/reference.out"

output_html = Path("/home/b085164/PDM_Romain_Defferrard/ESO-PDM/traj_scanline.html")

t_start = None
t_end   = None
max_display_points = 5000

# ------------------------------------------------------------
# SBET dtype
# ------------------------------------------------------------
SBET_DTYPE = np.dtype([
    ("time",    np.float64), ("lat",  np.float64), ("lon",   np.float64),
    ("alt",     np.float64), ("vx",   np.float64), ("vy",    np.float64),
    ("vz",      np.float64), ("roll", np.float64), ("pitch", np.float64),
    ("heading", np.float64), ("wander",np.float64),("ax",    np.float64),
    ("ay",      np.float64), ("az",   np.float64), ("wx",    np.float64),
    ("wy",      np.float64), ("wz",   np.float64),
])

def load_sbet(path):
    return pd.DataFrame(np.fromfile(path, dtype=SBET_DTYPE))

def filter_time_window(df, t0, t1):
    mask = np.ones(len(df), dtype=bool)
    if t0 is not None: mask &= df["time"].to_numpy() >= t0
    if t1 is not None: mask &= df["time"].to_numpy() <= t1
    return df.loc[mask].copy()

def decimate_idx(n, max_n):
    if n <= max_n:
        return np.arange(n)
    return np.linspace(0, n-1, max_n).astype(int)

# ------------------------------------------------------------
# LOAD DATA
# ------------------------------------------------------------
traj = filter_time_window(load_sbet(traj_path), t_start, t_end)
manifest = pd.read_csv(manifest_path)

# ------------------------------------------------------------
# MERGE ON TIME
# ------------------------------------------------------------
# ------------------------------------------------------------
# PREP MANIFEST
# ------------------------------------------------------------
manifest = manifest.sort_values("t_start").reset_index(drop=True)

t_start = manifest["t_start"].to_numpy()
t_end   = manifest["t_end"].to_numpy()
scan_id = manifest["scan_id"].to_numpy()

# ------------------------------------------------------------
# ASSIGN SCAN ID TO TRAJ
# ------------------------------------------------------------
t = traj["time"].to_numpy()

# trouve l'intervalle candidat
idx = np.searchsorted(t_start, t, side="right") - 1

# filtre valide (dans intervalle)
valid = (idx >= 0) & (t <= t_end[idx])

scan = np.full(len(t), -1, dtype=np.int32)
scan[valid] = scan_id[idx[valid]]

# ajoute au dataframe
traj["scan_id"] = scan

# garde seulement les points valides
df = traj[traj["scan_id"] >= 0].copy()

print("Points assignés à un scan:", len(df))

# ------------------------------------------------------------
# FIND SCAN LINE COLUMN
# ------------------------------------------------------------
scan_col = [c for c in df.columns if "scan" in c.lower()][0]
print("Scan column:", scan_col)

# ------------------------------------------------------------
# DECIMATE
# ------------------------------------------------------------
idx = decimate_idx(len(df), max_display_points)

lat = np.degrees(df["lat"].to_numpy()[idx])
lon = np.degrees(df["lon"].to_numpy()[idx])
scan = df[scan_col].to_numpy()[idx]
time = df["time"].to_numpy()[idx]

# ------------------------------------------------------------
# COLOR MAPPING
# ------------------------------------------------------------
# normalisation (robuste)
scan_norm = (scan - scan.min()) / (scan.max() - scan.min() + 1e-9)

# ------------------------------------------------------------
# COLOR MAP (DISCRETE)
# ------------------------------------------------------------
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

unique_scans = np.unique(scan)
n_scans = len(unique_scans)

# palette qualitative
cmap = plt.get_cmap("tab20", min(n_scans, 20))

scan_to_color = {}
for i, s in enumerate(unique_scans):
    color = mcolors.to_hex(cmap(i % 20))
    scan_to_color[s] = color

# ------------------------------------------------------------
# MAP
# ------------------------------------------------------------
center = [lat.mean(), lon.mean()]
m = folium.Map(
    location=center,
    zoom_start=14,
    max_zoom=22,
    tiles="https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
    attr="CartoDB"
)

# ------------------------------------------------------------
# DRAW TRAJ (by scan)
# ------------------------------------------------------------
for i in range(len(lat) - 1):
    s = scan[i]
    if s < 0:
        continue

    color = scan_to_color[s]

    folium.PolyLine(
        locations=[(lat[i], lon[i]), (lat[i+1], lon[i+1])],
        color=color,
        weight=3,
        opacity=0.9,
        tooltip=f"scan={s} | t={time[i]:.3f}"
    ).add_to(m)

# ------------------------------------------------------------
# LEGEND (LIMITED)
# ------------------------------------------------------------
MAX_LEGEND = 15  # évite une légende énorme

legend_items = list(scan_to_color.items())[:MAX_LEGEND]

legend_html = """
<div style="
position: fixed;
top: 30px;
right: 30px;
z-index: 1000;
background: white;
padding: 10px;
border-radius: 6px;
box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
font-size: 13px;
">
<b>Scan lines</b><br>
"""

for s, c in legend_items:
    legend_html += f'<span style="color:{c};">&#9632;</span> scan {s}<br>'

if n_scans > MAX_LEGEND:
    legend_html += "<i>... others</i><br>"

legend_html += "</div>"

m.get_root().html.add_child(folium.Element(legend_html))

# ------------------------------------------------------------
# SAVE
# ------------------------------------------------------------
m.save(str(output_html))
print(f"Saved: {output_html}")
# Out:
# Points assignés à un scan: 10700
# Scan column: scan_id
# Saved: /home/b085164/PDM_Romain_Defferrard/ESO-PDM/traj_scanline.html

# %%
print(manifest.columns)
# Out:
# Index(['scan_id', 'filename', 't_start', 't_end'], dtype='object')

# %%
# ==============================================================
# CELL 1 — CONFIG
# ==============================================================
import numpy as np
import laspy
import pandas as pd
from pathlib import Path
import sys
sys.path.insert(0, "/home/b085164/PDM_Romain_Defferrard/ESO-PDM")

BASE_DIR = Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/merged/ALL")
OUT_BASE = Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/crop_v2")
OUT_BASE.mkdir(parents=True, exist_ok=True)

LIMATCH_CFG = "/home/b085164/PDM_Romain_Defferrard/ESO-PDM/Patcher/submodules/limatch/configs/MLS_F2B_1_APX.yml"


PAIRS = [
    ( 9000, (305812, 305824), 10000, (305849, 305858)),   # 0 DONE [4, 6.5]
    (19000, (306101, 306105),  1000, (305695, 305703)),   # 1 DONE [2, 3] lcd 1 rsc 0.5
    (18000, (305954, 305960), 19000, (306090, 306096)),   # 2 DONE [20, 21]
    (18000, (305975, 305985), 19000, (306068, 306077)),   # 3 DONE [17.5, 19]
    (18000, (306004, 306022), 19000, (306027, 306050)),   # 4  [11, 12.5] lcp 2, augmenter kpts
    ( 2000, (305724, 305733), 13000, (305904, 305910)),   # 5 DONE [15, 16.5]
    ( 2000, (305724, 305733),  9000, (305796, 305805)),   # 6 DONE [9.5, 11.5]
    ( 4000, (305744, 305754),  7000, (305776, 305785)),   # 7 DONE []
    ( 4000, (305744, 305754), 11000, (305886, 305891)),   # 8 DONE [11, 13]
    ( 4000, (305744, 305754), 15000, (305920, 305927)),   # 9 DONE [10, 12]
    (11000, (305886, 305891), 15000, (305920, 305927)),   # 10 [0, 2]
    ( 4000, (305755, 305763),  2000, (305706, 305723)),   # 11 [5, 7]
    ( 4000, (305745, 305752), 18000, (305955, 305962)),   # 12 [9, 11]
    (18000, (305953, 305958), 19000, (306094, 306098)),   # 13 PAS A FAIRE []
    (17000, (305939, 305947),  2000, (305721, 305729)),   # 14 DONE [13, 14.5]
    (16000, (305932, 305944),  9000, (305800, 305810)),   # 15
    (18000, (305953, 305960), 7000, (305775, 305785)),   # 16 
]

print(f"{len(PAIRS)} paires configurées")
for i, (sa, ta, sb, tb) in enumerate(PAIRS):
    print(f"  [{i:2d}] merged_{sa} [{ta[0]}-{ta[1]}] ↔ merged_{sb} [{tb[0]}-{tb[1]}]")
# Out:
# 17 paires configurées
#   [ 0] merged_9000 [305812-305824] ↔ merged_10000 [305849-305858]
#   [ 1] merged_19000 [306101-306105] ↔ merged_1000 [305695-305703]
#   [ 2] merged_18000 [305954-305960] ↔ merged_19000 [306090-306096]
#   [ 3] merged_18000 [305975-305985] ↔ merged_19000 [306068-306077]
#   [ 4] merged_18000 [306004-306022] ↔ merged_19000 [306027-306050]
#   [ 5] merged_2000 [305724-305733] ↔ merged_13000 [305904-305910]
#   [ 6] merged_2000 [305724-305733] ↔ merged_9000 [305796-305805]
#   [ 7] merged_4000 [305744-305754] ↔ merged_7000 [305776-305785]
#   [ 8] merged_4000 [305744-305754] ↔ merged_11000 [305886-305891]
#   [ 9] merged_4000 [305744-305754] ↔ merged_15000 [305920-305927]
#   [10] merged_11000 [305886-305891] ↔ merged_15000 [305920-305927]
#   [11] merged_4000 [305755-305763] ↔ merged_2000 [305706-305723]
#   [12] merged_4000 [305745-305752] ↔ merged_18000 [305955-305962]
#   [13] merged_18000 [305953-305958] ↔ merged_19000 [306094-306098]
#   [14] merged_17000 [305939-305947] ↔ merged_2000 [305721-305729]
#   [15] merged_16000 [305932-305944] ↔ merged_9000 [305800-305810]
#   [16] merged_18000 [305953-305960] ↔ merged_7000 [305775-305785]

# %%
# ==============================================================
# CELL 2 — CROP optimisé (une lecture par fichier source)
# ==============================================================
from collections import defaultdict

def crop_las_by_time_fast(las_path, crops):
    """
    crops : list de (t0, t1, out_path)
    Lit le fichier une seule fois et écrit tous les crops.
    """
    # Filtre les crops déjà faits
    todo = [(t0, t1, p) for t0, t1, p in crops if not p.exists()]
    done = [(t0, t1, p) for t0, t1, p in crops if p.exists()]

    for _, _, p in done:
        print(f"    [SKIP] {p.name}")

    if not todo:
        return

    print(f"    Lecture {las_path.name}...", end=" ", flush=True)
    las = laspy.read(las_path)
    t   = np.asarray(las.gps_time)
    print(f"{len(t):,} pts")

    for t0, t1, out_path in todo:
        mask   = (t >= t0) & (t <= t1)
        n_kept = int(mask.sum())
        print(f"    [{t0}-{t1}] → {n_kept:,} pts", end=" ")
        if n_kept == 0:
            print("!! vide")
            continue
        las[mask].write(out_path)
        print(f"→ {out_path.name}")

# Groupe les crops par fichier source
file_to_crops = defaultdict(list)  # {las_path: [(t0, t1, out_path, pair_idx, role)]}

for i, (sid_a, t_crop_a, sid_b, t_crop_b) in enumerate(PAIRS):
    out_dir = OUT_BASE / f"pair_{i:02d}_{sid_a}_{sid_b}"
    out_dir.mkdir(parents=True, exist_ok=True)
    file_to_crops[BASE_DIR / f"merged_{sid_a}_VUX_PUCK.las"].append(
        (*t_crop_a, out_dir / f"scan_{sid_a}_crop.las"))
    file_to_crops[BASE_DIR / f"merged_{sid_b}_VUX_PUCK.las"].append(
        (*t_crop_b, out_dir / f"scan_{sid_b}_crop.las"))

# Une seule lecture par fichier source
for las_path, crops in sorted(file_to_crops.items()):
    print(f"\n  {las_path.name}  ({len(crops)} crops)")
    crop_las_by_time_fast(las_path, crops)

# Reconstruit crop_paths
crop_paths = {}
for i, (sid_a, t_crop_a, sid_b, t_crop_b) in enumerate(PAIRS):
    out_dir = OUT_BASE / f"pair_{i:02d}_{sid_a}_{sid_b}"
    path_a  = out_dir / f"scan_{sid_a}_crop.las"
    path_b  = out_dir / f"scan_{sid_b}_crop.las"
    crop_paths[i] = (
        out_dir,
        path_a if path_a.exists() else None,
        path_b if path_b.exists() else None,
    )

n_ok = sum(1 for v in crop_paths.values() if v[1] and v[2])
print(f"\n{n_ok}/{len(PAIRS)} paires prêtes.")
# Out:
#   merged_10000_VUX_PUCK.las  (1 crops)
#     [SKIP] scan_10000_crop.las
#
#   merged_1000_VUX_PUCK.las  (1 crops)
#     [SKIP] scan_1000_crop.las
#
#   merged_11000_VUX_PUCK.las  (2 crops)
#     [SKIP] scan_11000_crop.las
#     [SKIP] scan_11000_crop.las
#
#   merged_13000_VUX_PUCK.las  (1 crops)
#     [SKIP] scan_13000_crop.las
#
#   merged_15000_VUX_PUCK.las  (2 crops)
#     [SKIP] scan_15000_crop.las
#     [SKIP] scan_15000_crop.las
#
#   merged_16000_VUX_PUCK.las  (1 crops)
#     [SKIP] scan_16000_crop.las
#
#   merged_17000_VUX_PUCK.las  (1 crops)
#     [SKIP] scan_17000_crop.las
#
#   merged_18000_VUX_PUCK.las  (6 crops)
#     [SKIP] scan_18000_crop.las
#     [SKIP] scan_18000_crop.las
#     [SKIP] scan_18000_crop.las
#     [SKIP] scan_18000_crop.las
#     [SKIP] scan_18000_crop.las
#     Lecture merged_18000_VUX_PUCK.las... 76,557,827 pts
#     [305953-305960] → 6,860,492 pts → scan_18000_crop.las
#
#   merged_19000_VUX_PUCK.las  (5 crops)
#     [SKIP] scan_19000_crop.las
#     [SKIP] scan_19000_crop.las
#     [SKIP] scan_19000_crop.las
#     [SKIP] scan_19000_crop.las
#     [SKIP] scan_19000_crop.las
#
#   merged_2000_VUX_PUCK.las  (4 crops)
#     [SKIP] scan_2000_crop.las
#     [SKIP] scan_2000_crop.las
#     [SKIP] scan_2000_crop.las
#     [SKIP] scan_2000_crop.las
#
#   merged_4000_VUX_PUCK.las  (5 crops)
#     [SKIP] scan_4000_crop.las
#     [SKIP] scan_4000_crop.las
#     [SKIP] scan_4000_crop.las
#     [SKIP] scan_4000_crop.las
#     [SKIP] scan_4000_crop.las
#
#   merged_7000_VUX_PUCK.las  (2 crops)
#     [SKIP] scan_7000_crop.las
#     Lecture merged_7000_VUX_PUCK.las... 10,655,034 pts
#     [305775-305785] → 9,713,552 pts → scan_7000_crop.las
#
#   merged_9000_VUX_PUCK.las  (3 crops)
#     [SKIP] scan_9000_crop.las
#     [SKIP] scan_9000_crop.las
#     [SKIP] scan_9000_crop.las
#
# 17/17 paires prêtes.

# %%
# ==============================================================
# CELL 3 — LANCER LIMATCH (sélection par index)
# ==============================================================
from navtools_PDM.pipeline import run_limatch_api, get_repo_root

repo_root = get_repo_root()

# ← Modifie cette liste pour choisir les paires à lancer
PAIRS_TO_RUN = [16]   # indices dans PAIRS

limatch_results = {}  # {pair_idx: (out_dir, corres_path)}

# Charge d'abord les résultats existants sur disque
for i in range(len(PAIRS)):
    out_dir = crop_paths[i][0]
    lm_dir  = out_dir / "limatch"
    existing = list(lm_dir.rglob("corres_*.txt"))
    if existing:
        limatch_results[i] = (out_dir, existing[0])

print(f"{len(limatch_results)} paires avec corres existants sur disque")
print(f"Paires à lancer : {PAIRS_TO_RUN}\n")

for i in PAIRS_TO_RUN:
    out_dir, path_a, path_b = crop_paths[i]
    lm_dir = out_dir / "limatch"

    if i in limatch_results:
        print(f"[{i:2d}] SKIP — {limatch_results[i][1].name}")
        continue

    if path_a is None or path_b is None:
        print(f"[{i:2d}] SKIP — crop vide")
        continue

    print(f"\n[{i:2d}] LiMatch — {path_a.name} / {path_b.name}")
    run_limatch_api(
        repo_root=repo_root,
        limatch_cfg_path=LIMATCH_CFG,
        cloud1=path_a,
        cloud2=path_b,
        out_dir=lm_dir,
    )

    corres_files = list(lm_dir.rglob("corres_*.txt"))
    if corres_files:
        limatch_results[i] = (out_dir, corres_files[0])
        print(f"  → {corres_files[0].name}")
    else:
        print(f"  !! Pas de corres_*.txt")

print(f"\n{len(limatch_results)}/{len(PAIRS)} paires avec correspondances.")
# Out:
# [09:06:14] INFO | Starting LiMatch pipeline...
# [09:06:14] INFO |   └─ Will save data at: /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/crop_v2/pair_16_18000_7000/limatch/
# [09:06:14] INFO | Visualization set to False
# [09:06:14] INFO | [0/7] Model setup
# [09:06:14] INFO |   └─ Using CUDA for descriptor inference.
# [09:06:14] INFO |   └─ Loading from: /home/b085164/PDM_Romain_Defferrard/ESO-PDM/Patcher/submodules/limatch/weights/model.pth
# [09:06:14] INFO |   └─ Loaded nested checkpoint with key 'model'.
# [09:06:14] INFO |   └─ Descriptor model successfully loaded and set to eval() mode.
# [09:06:14] INFO | [1/7] Preprocessing
# [09:06:14] INFO |   └─ Loading point clouds...
# 11 paires avec corres existants sur disque
# Paires à lancer : [16]
#
#
# [16] LiMatch — scan_18000_crop.las / scan_7000_crop.las
# [limatch-api] prj_folder=/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/crop_v2/pair_16_18000_7000/limatch/
# [09:06:14] INFO |   └─ Loaded laser vectors from LAS extra bytes: /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/crop_v2/pair_16_18000_7000/scan_18000_crop.las
# [09:06:15] INFO |   └─ Loaded laser vectors from LAS extra bytes: /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/crop_v2/pair_16_18000_7000/scan_7000_crop.las
# [09:06:17] INFO |   └─ No tiling... (all points kept)
# [09:06:17] INFO |   └─ Shifting point clouds toward origin...
# [09:06:17] INFO |       └─ [2542665.7  1157344.93     905.1 ] m...
# [09:06:17] INFO |       └─ (Coordinates shifted back at export)
# [09:06:20] INFO |   └─ Generated 1 valid tiles.
# [09:06:20] INFO |   └─ Applying voxelization with size 0.025 m...
# [09:06:23] INFO |       └─ voxelized from 6860492 to 2838307 pts (41.37%)
# [09:06:29] INFO |       └─ voxelized from 9713552 to 3659670 pts (37.68%)
# [09:06:30] INFO | [2/7] Keypoint detection
# [09:06:37] INFO |   └─ Deleting kpts without candidate in radius 2*6m...
# [09:06:37] INFO |       └─ 27225 keypoints kept (98.59%)
# [09:06:37] INFO |       └─ 33852 keypoints kept (92.87%)
# [09:06:37] INFO | [3/7] Description
# [09:06:37] INFO |   └─ Computing descriptors for Tile A...
# [09:06:37] INFO |       └─ batch 1/1...
# [09:06:50] INFO |   └─ Computing descriptors for Tile B...
# [09:06:50] INFO |       └─ batch 1/1...
# [09:07:16] INFO | [4/7] Matching
# [09:07:16] INFO |   └─ get_candidates A→B (27225 kpts)...
# [09:07:16] INFO |   └─ get_candidates — r_min=8.0m  r_max=12.0m  (27225 kpts)
# [09:07:23] INFO |   └─ get_candidates 100% — avg candidates/kpt: 1688
# [09:07:24] INFO |   └─ get_candidates B→A (33852 kpts)...
# [09:07:24] INFO |   └─ get_candidates — r_min=8.0m  r_max=12.0m  (33852 kpts)
# [09:07:31] INFO |   └─ get_candidates 100% — avg candidates/kpt: 1357
# [09:07:31] INFO |   └─ feat_search A→B (27225 kpts)...
# [09:07:36] INFO |   └─ feat_search B→A (33852 kpts)...
# [09:07:41] INFO |   └─ feat_search — 148 kpts sans candidats (ignorés)
# [09:07:41] INFO |   └─ Applying reciprocity test...
# [09:07:41] INFO |   └─ Keeping 6.91% reciprocal matches
# [09:07:41] INFO | [5/7] RANSAC filtering
# [09:07:41] INFO |   └─ Tile 1: keeping 14.73%
# [09:07:41] INFO | [6/7] ICP refinement
# [09:07:41] INFO |   └─ ICP refining tile 1 with 277 correspondences...
# [09:08:05] INFO | [7/7] Building output
# [09:08:05] INFO |   └─ Loading trajectory from SBET: /media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B_z2/out/F2B_out2_apx.out...
# [09:08:05] INFO |       └─ Loaded 39901 trajectory points.
# [09:08:05] INFO |       └─ Time span: 304790.004807 to 306785.0048065355 s.
# [09:08:06] INFO |   └─ Using input laser vectors for correspondences...
# [09:08:06] INFO |   └─ Correcting laser vectors B with ICP results...
# [09:08:06] INFO |   └─ Saving to /media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/georef_F2B/crop_v2/pair_16_18000_7000/limatch/cor_outputs/
# [09:08:07] INFO | [Pipeline summary]
# [09:08:07] INFO |       Model setup: 0.08s
# [09:08:07] INFO |     Preprocessing: 16.10s
# [09:08:07] INFO |         Detection: 7.25s
# [09:08:07] INFO |       Description: 39.11s
# [09:08:07] INFO |          Matching: 24.52s
# [09:08:07] INFO |            RANSAC: 0.02s
# [09:08:07] INFO |               ICP: 24.77s
# [09:08:07] INFO |             Total: 113.53s
# [09:08:07] INFO | [Metrics]
# [09:08:07] INFO |          Points A: 2818536
# [09:08:07] INFO |          Points B: 3640628
# [09:08:07] INFO |        Tiles num.: 1
# [09:08:07] INFO |       Keypoints A: 27225
# [09:08:07] INFO |       Keypoints B: 33852
# [09:08:07] INFO |       Raw matches: 1881
# [09:08:07] INFO |    RANSAC matches: 277
# [09:08:07] INFO | Peak RAM: 7.90 GB
# [09:08:07] INFO | LiMatch pipeline completed.
#   → corres_scan_18000_crop_scan_7000_crop.txt
#
# 12/17 paires avec correspondances.

# %% [markdown]
# # L2L distance Discussion

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# ============================================================
# INPUTS
# ============================================================

SCENARIOS = {
    "Outage 1 — AIRINS": Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_1/limatch_F2B_v3"),
    "Outage 2 — AIRINS": Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/limatch_F2B_v2"),
    "Outage 3 — AIRINS": Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_3/limatch_F2B_v2"),
    "Outage 1 — APX15":  Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_1/APX/limatch_F2B"),
    "Outage 2 — APX15":  Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_2/APX/limatch_F2B_v1"),
    "Outage 3 — APX15":  Path("/media/b085164/Elements/CALIB_26_02_25/georef_ALL_traj_outage_3/APX/limatch_F2B"),
}

CORRES_COLS = ["time_a","x_a","y_a","z_a",
               "time_b","x_b","y_b","z_b",
               "d_xyz","icp_x","icp_y","icp_z"]

# ============================================================
# CHARGEMENT
# ============================================================

def load_all_corres(root: Path) -> np.ndarray:
    """Charge tous les fichiers corres_*.txt sous root récursivement."""
    all_d = []
    files = list(root.rglob("corres_*.txt"))
    if not files:
        print(f"  WARNING: aucun fichier trouvé sous {root}")
        return np.array([])
    for f in files:
        try:
            df = pd.read_csv(f, header=None, names=CORRES_COLS,
                             sep=r",\s*", engine="python", skiprows=1)
            df = df.apply(pd.to_numeric, errors="coerce").dropna()
            if "d_xyz" in df.columns and len(df) > 0:
                all_d.append(df["d_xyz"].values)
        except Exception as e:
            print(f"  Skipping {f.name}: {e}")
    if not all_d:
        return np.array([])
    return np.concatenate(all_d) * 1000  # → mm

# ============================================================
# STATS
# ============================================================

results = {}

print(f"{'Scenario':<25} {'N':>8} {'Q50 [mm]':>10} {'Q75 [mm]':>10} "
      f"{'Q90 [mm]':>10} {'Q95 [mm]':>10} {'Mean [mm]':>10}")
print("-" * 90)

for label, root in SCENARIOS.items():
    d = load_all_corres(root)
    if len(d) == 0:
        print(f"  {label:<23} — no data")
        continue
    results[label] = d
    print(f"  {label:<23} {len(d):>8} "
          f"{np.percentile(d,50):>10.2f} "
          f"{np.percentile(d,75):>10.2f} "
          f"{np.percentile(d,90):>10.2f} "
          f"{np.percentile(d,95):>10.2f} "
          f"{np.mean(d):>10.2f}")

# ============================================================
# PLOT
# ============================================================

fig, axes = plt.subplots(2, 3, figsize=(14, 7), sharey=False)
axes = axes.flatten()

for ax, (label, d) in zip(axes, results.items()):
    q50 = np.percentile(d, 50)
    q95 = np.percentile(d, 95)
    # Clip pour la lisibilité
    d_clip = d[d < np.percentile(d, 99)]
    ax.hist(d_clip, bins=80, color="#2980B9", edgecolor="none", alpha=0.8)
    ax.axvline(q50, color="orange", lw=2, label=f"Q50={q50:.1f}mm")
    ax.axvline(q95, color="red", lw=2, linestyle="--", label=f"Q95={q95:.1f}mm")
    ax.set_title(label, fontsize=10)
    ax.set_xlabel("d_xyz [mm]")
    ax.set_ylabel("Count")
    ax.legend(fontsize=8)

plt.suptitle("F2B correspondence distance distribution per scenario", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Scenario                         N   Q50 [mm]   Q75 [mm]   Q90 [mm]   Q95 [mm]  Mean [mm]
# ------------------------------------------------------------------------------------------
#   Outage 1 — AIRINS         163252      31.00      41.00      60.00      98.00      37.83
#   Outage 2 — AIRINS         156443      33.00      53.00      92.00     191.00      49.90
#   Outage 3 — AIRINS         342502      54.00     116.00     165.00     202.00      77.02
#   Outage 1 — APX15           64887     736.00    1794.00    2537.00    4692.40    1239.90
#   Outage 2 — APX15           39899     268.00     401.00     923.00    1258.00     393.85
#   Outage 3 — APX15           29474     261.00     635.00    1127.00    1839.05     482.06

# %% [markdown]
# # Debug outage 2 apx

# %%
# Colle ça dans une cellule et montre-moi le output
import numpy as np
from pathlib import Path

P2P_A = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/in/LiDAR_p2p.txt")
P2P_B = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/in/v2/LiDAR_p2p.txt")

for p in [P2P_A, P2P_B]:
    with open(p) as f:
        lines = f.readlines()
    print(f"=== {p.name} ===")
    print(f"  {len(lines)} lignes")
    print(f"  header : {[l for l in lines[:5] if l.startswith('#')]}")
    print(f"  ligne 1 : {lines[0] if not lines[0].startswith('#') else lines[-1]}")
    print()
# Out:
# === LiDAR_p2p.txt ===
#   39899 lignes
#   header : []
#   ligne 1 : 305635.986268959, 305635.304456246, -18.5717, -15.3996, 0.3910, -8.2263, -15.3413, 0.636
#
#
# === LiDAR_p2p.txt ===
#   50011 lignes
#   header : []
#   ligne 1 : 305838.579650694, 305836.758808704, -5.1003, 2.7245, -1.9309, 1.5029, 4.9898, -1.8193

# %%
# ── CELL 1 — Chargement ──────────────────────────────────────
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

COLS = ['time_a', 'time_b', 'dx_a', 'dy_a', 'dz_a', 'dx_b', 'dy_b', 'dz_b']

P2P = {
    'Run 1': Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/in/LiDAR_p2p.txt"),
    'Run 2': Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/in/v2/LiDAR_p2p.txt"),
}

# Bornes temporelles de l'outage
T_OUTAGE_START = 305645.0
T_OUTAGE_END   = 306120.0

dfs = {}
for label, path in P2P.items():
    df = pd.read_csv(path, header=None, names=COLS)
    dfs[label] = df
    print(f"=== {label} ===")
    print(f"  {len(df):,} correspondances")
    print(f"  time_a : [{df.time_a.min():.1f}, {df.time_a.max():.1f}]")
    print(f"  time_b : [{df.time_b.min():.1f}, {df.time_b.max():.1f}]")
    print(f"  Δt = time_b - time_a : "
          f"min={( df.time_b - df.time_a).min():.1f}  "
          f"max={(df.time_b - df.time_a).max():.1f}  "
          f"median={(df.time_b - df.time_a).median():.1f} s")
    print()
# Out:
# === Run 1 ===
#   39,899 correspondances
#   time_a : [305636.0, 306130.0]
#   time_b : [305635.0, 306117.4]
#   Δt = time_b - time_a : min=-14.0  max=-0.0  median=-1.2 s
#
# === Run 2 ===
#   50,011 correspondances
#   time_a : [305616.9, 306150.0]
#   time_b : [305615.9, 306147.6]
#   Δt = time_b - time_a : min=-14.7  max=-0.0  median=-1.3 s

# %%
# ── CELL 2 — Distribution temporelle des correspondances ─────
fig, axes = plt.subplots(2, 2, figsize=(15, 8))

COLORS = {'Run 1': '#e74c3c', 'Run 2': '#27ae60'}

for col_i, t_col in enumerate(['time_a', 'time_b']):
    ax_top = axes[0, col_i]
    ax_bot = axes[1, col_i]

    for label, df in dfs.items():
        color = COLORS[label]
        # Histogramme de densité temporelle
        ax_top.hist(df[t_col], bins=100, alpha=0.6, color=color,
                    label=f"{label} (N={len(df):,})", density=True)

    ax_top.axvline(T_OUTAGE_START, color='black', lw=1.2, ls='--', label='Outage start/end')
    ax_top.axvline(T_OUTAGE_END,   color='black', lw=1.2, ls='--')
    ax_top.set_title(f"Densité temporelle — {t_col}", fontweight='bold')
    ax_top.set_xlabel("GPS time (SOW, s)")
    ax_top.set_ylabel("Densité")
    ax_top.legend(fontsize=8)

    # Cumulatif
    for label, df in dfs.items():
        color = COLORS[label]
        t_sorted = np.sort(df[t_col].values)
        cdf = np.arange(1, len(t_sorted)+1) / len(t_sorted)
        ax_bot.plot(t_sorted, cdf, color=color, lw=1.5, label=label)

    ax_bot.axvline(T_OUTAGE_START, color='black', lw=1.2, ls='--')
    ax_bot.axvline(T_OUTAGE_END,   color='black', lw=1.2, ls='--')
    ax_bot.set_title(f"CDF temporelle — {t_col}", fontweight='bold')
    ax_bot.set_xlabel("GPS time (SOW, s)")
    ax_bot.set_ylabel("CDF")
    ax_bot.legend(fontsize=8)

fig.suptitle("Distribution temporelle des correspondances LiDAR p2p", fontsize=12)
fig.tight_layout()
plt.show()

# %%
# ── CELL 3 — Couverture dans l'outage ────────────────────────
print("Correspondances DANS l'outage [time_a dans [T_START, T_END]] :\n")

for label, df in dfs.items():
    mask_in  = (df.time_a >= T_OUTAGE_START) & (df.time_a <= T_OUTAGE_END)
    mask_out = ~mask_in
    df_in    = df[mask_in]

    print(f"  {label} : {len(df_in):,} / {len(df):,} corres dans l'outage "
          f"({100*len(df_in)/len(df):.1f} %)")

    if len(df_in) == 0:
        print("    !! Aucune correspondance dans l'outage")
        continue

    # Découpe en segments de 10s
    bins = np.arange(T_OUTAGE_START, T_OUTAGE_END + 10, 10)
    counts, _ = np.histogram(df_in.time_a, bins=bins)
    print(f"    Corres par tranche de 10s :")
    for i, c in enumerate(counts):
        t0 = bins[i]; t1 = bins[i+1]
        bar = '█' * min(c // 10, 50)
        print(f"    [{t0:.0f}-{t1:.0f}]  {c:5d}  {bar}")
    print()
# Out:
# Correspondances DANS l'outage [time_a dans [T_START, T_END]] :
#
#   Run 1 : 38,276 / 39,899 corres dans l'outage (95.9 %)
#     Corres par tranche de 10s :
#     [305645-305655]   4526  ██████████████████████████████████████████████████
#     [305655-305665]   4999  ██████████████████████████████████████████████████
#     [305665-305675]   7386  ██████████████████████████████████████████████████
#     [305675-305685]  11597  ██████████████████████████████████████████████████
#     [305685-305695]   2024  ██████████████████████████████████████████████████
#     [305695-305705]      0
#     [305705-305715]      0
#     [305715-305725]      0
#     [305725-305735]      0
#     [305735-305745]      0
#     [305745-305755]      0
#     [305755-305765]      0
#     [305765-305775]      0
#     [305775-305785]      0
#     [305785-305795]      0
#     [305795-305805]      0
#     [305805-305815]     19  █
#     [305815-305825]     48  ████
#     [305825-305835]      0
#     [305835-305845]      0
#     [305845-305855]      0
#     [305855-305865]   1141  ██████████████████████████████████████████████████
#     [305865-305875]   3101  ██████████████████████████████████████████████████
#     [305875-305885]    252  █████████████████████████
#     [305885-305895]      0
#     [305895-305905]      0
#     [305905-305915]     95  █████████
#     [305915-305925]      0
#     [305925-305935]      0
#     [305935-305945]      0
#     [305945-305955]      0
#     [305955-305965]      0
#     [305965-305975]    705  ██████████████████████████████████████████████████
#     [305975-305985]      0
#     [305985-305995]      0
#     [305995-306005]      0
#     [306005-306015]      0
#     [306015-306025]      0
#     [306025-306035]      0
#     [306035-306045]      0
#     [306045-306055]      0
#     [306055-306065]      0
#     [306065-306075]     90  █████████
#     [306075-306085]    170  █████████████████
#     [306085-306095]    511  ██████████████████████████████████████████████████
#     [306095-306105]    241  ████████████████████████
#     [306105-306115]    839  ██████████████████████████████████████████████████
#     [306115-306125]    532  ██████████████████████████████████████████████████
#
#   Run 2 : 36,835 / 50,011 corres dans l'outage (73.7 %)
#     Corres par tranche de 10s :
#     [305645-305655]   2642  ██████████████████████████████████████████████████
#     [305655-305665]   2649  ██████████████████████████████████████████████████
#     [305665-305675]   3467  ██████████████████████████████████████████████████
#     [305675-305685]   7063  ██████████████████████████████████████████████████
#     [305685-305695]   1291  ██████████████████████████████████████████████████
#     [305695-305705]    102  ██████████
#     [305705-305715]    351  ███████████████████████████████████
#     [305715-305725]    251  █████████████████████████
#     [305725-305735]     59  █████
#     [305735-305745]     87  ████████
#     [305745-305755]    189  ██████████████████
#     [305755-305765]      0
#     [305765-305775]      0
#     [305775-305785]      0
#     [305785-305795]      0
#     [305795-305805]    109  ██████████
#     [305805-305815]    441  ████████████████████████████████████████████
#     [305815-305825]    500  ██████████████████████████████████████████████████
#     [305825-305835]     30  ███
#     [305835-305845]     80  ████████
#     [305845-305855]      5
#     [305855-305865]   2236  ██████████████████████████████████████████████████
#     [305865-305875]   3033  ██████████████████████████████████████████████████
#     [305875-305885]    821  ██████████████████████████████████████████████████
#     [305885-305895]    203  ████████████████████
#     [305895-305905]      7
#     [305905-305915]   1037  ██████████████████████████████████████████████████
#     [305915-305925]    155  ███████████████
#     [305925-305935]    114  ███████████
#     [305935-305945]     54  █████
#     [305945-305955]    157  ███████████████
#     [305955-305965]    103  ██████████
#     [305965-305975]   2696  ██████████████████████████████████████████████████
#     [305975-305985]    927  ██████████████████████████████████████████████████
#     [305985-305995]    890  ██████████████████████████████████████████████████
#     [305995-306005]    886  ██████████████████████████████████████████████████
#     [306005-306015]     70  ███████
#     [306015-306025]      0
#     [306025-306035]     93  █████████
#     [306035-306045]     69  ██████
#     [306045-306055]     64  ██████
#     [306055-306065]    153  ███████████████
#     [306065-306075]    320  ████████████████████████████████
#     [306075-306085]   1110  ██████████████████████████████████████████████████
#     [306085-306095]    673  ██████████████████████████████████████████████████
#     [306095-306105]    396  ███████████████████████████████████████
#     [306105-306115]    793  ██████████████████████████████████████████████████
#     [306115-306125]    459  █████████████████████████████████████████████

# %%
# ── CELL 4 — Analyse spatiale (scatter XY des points A) ──────
# Nécessite les fichiers corres_*.txt (avec XYZ) si disponibles,
# sinon on travaille avec les timestamps uniquement

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, (label, df) in zip(axes, dfs.items()):
    color = COLORS[label]
    mask_in = (df.time_a >= T_OUTAGE_START) & (df.time_a <= T_OUTAGE_END)

    # Δt entre les deux points de chaque correspondance
    dt = (df.time_b - df.time_a).abs()

    sc = ax.scatter(df.time_a, dt, s=1, alpha=0.3, c=mask_in.astype(int),
                    cmap='RdYlGn', vmin=0, vmax=1)
    ax.axvline(T_OUTAGE_START, color='black', lw=1.2, ls='--')
    ax.axvline(T_OUTAGE_END,   color='black', lw=1.2, ls='--')
    ax.set_xlabel("time_a (SOW, s)")
    ax.set_ylabel("|Δt| entre corres (s)")
    ax.set_title(f"{label}\nvert=dans outage  rouge=hors outage", fontweight='bold')
    ax.set_yscale('log')

fig.suptitle("|Δt| des correspondances vs temps", fontsize=12)
fig.tight_layout()
plt.show()

# %%
# ── CELL 5 — Qualité des correspondances : angle entre vecteurs laser ──
# dx_a/dy_a/dz_a et dx_b/dy_b/dz_b sont les directions des lasvecs
# Pour une bonne correspondance, les deux vecteurs doivent être quasi-parallèles
# (même surface vue depuis deux positions proches)
# Un grand angle → faux match ou géométrie incompatible

import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(15, 9))

for col_i, (label, df) in enumerate(dfs.items()):
    # Normalise les vecteurs
    va = df[['dx_a','dy_a','dz_a']].values
    vb = df[['dx_b','dy_b','dz_b']].values
    va_n = va / np.linalg.norm(va, axis=1, keepdims=True)
    vb_n = vb / np.linalg.norm(vb, axis=1, keepdims=True)

    # Angle entre les deux vecteurs (en degrés)
    cos_angle = np.clip((va_n * vb_n).sum(axis=1), -1, 1)
    angle_deg = np.degrees(np.arccos(cos_angle))

    mask_in = (df.time_a >= T_OUTAGE_START) & (df.time_a <= T_OUTAGE_END)

    # Scatter : angle vs time_a
    ax = axes[0, col_i]
    ax.scatter(df.time_a[mask_in],  angle_deg[mask_in],
               s=1, alpha=0.3, color='#27ae60', label='dans outage')
    ax.scatter(df.time_a[~mask_in], angle_deg[~mask_in],
               s=1, alpha=0.3, color='#e74c3c', label='hors outage')
    ax.axvline(T_OUTAGE_START, color='black', lw=1, ls='--')
    ax.axvline(T_OUTAGE_END,   color='black', lw=1, ls='--')
    ax.axhline(90, color='orange', lw=0.8, ls='--', alpha=0.7, label='90°')
    ax.set_xlabel("time_a (SOW, s)")
    ax.set_ylabel("Angle entre lasvecs (°)")
    ax.set_title(f"{label} — angle lasvec A↔B", fontweight='bold')
    ax.legend(fontsize=7, markerscale=5)

    # Histogramme de l'angle dans l'outage seulement
    ax2 = axes[1, col_i]
    ax2.hist(angle_deg[mask_in], bins=60, color='#27ae60', alpha=0.7,
             label=f'dans outage (N={mask_in.sum():,})')
    ax2.axvline(np.median(angle_deg[mask_in]), color='black', lw=1.5,
                ls='--', label=f"médiane={np.median(angle_deg[mask_in]):.1f}°")
    ax2.axvline(np.percentile(angle_deg[mask_in], 95), color='red', lw=1.5,
                ls=':', label=f"Q95={np.percentile(angle_deg[mask_in], 95):.1f}°")
    ax2.set_xlabel("Angle lasvec A↔B (°)")
    ax2.set_ylabel("N correspondances")
    ax2.set_title(f"{label} — distribution de l'angle (dans outage)", fontweight='bold')
    ax2.legend(fontsize=8)

    print(f"{label} — angle dans l'outage :")
    print(f"  médiane={np.median(angle_deg[mask_in]):.2f}°  "
          f"Q95={np.percentile(angle_deg[mask_in], 95):.2f}°  "
          f"max={angle_deg[mask_in].max():.2f}°")
    print(f"  % angle > 90° : {100*(angle_deg[mask_in]>90).mean():.1f}%")
    print(f"  % angle > 45° : {100*(angle_deg[mask_in]>45).mean():.1f}%")
    print()

fig.suptitle("Qualité géométrique des correspondances — angle entre vecteurs laser",
             fontsize=12)
fig.tight_layout()
plt.show()
# Out:
# Run 1 — angle dans l'outage :
#   médiane=79.12°  Q95=94.92°  max=174.45°
#   % angle > 90° : 26.6%
#   % angle > 45° : 85.7%
#
# Run 2 — angle dans l'outage :
#   médiane=61.53°  Q95=94.72°  max=159.50°
#   % angle > 90° : 15.1%
#   % angle > 45° : 67.0%

# %%
# ── CELL 6 — Résumé : densité de corres par tranche de 10s ───────────────
# Montre côte à côte Run1 vs Run2 pour voir exactement où chacun a des corres

bins = np.arange(T_OUTAGE_START, T_OUTAGE_END + 10, 10)
bin_centers = (bins[:-1] + bins[1:]) / 2

fig, axes = plt.subplots(2, 1, figsize=(14, 7), sharex=True)

for ax, (label, df) in zip(axes, dfs.items()):
    mask_in = (df.time_a >= T_OUTAGE_START) & (df.time_a <= T_OUTAGE_END)
    counts, _ = np.histogram(df.time_a[mask_in], bins=bins)

    color = '#e74c3c' if 'Run 1' in label else '#27ae60'
    ax.bar(bin_centers, counts, width=9, color=color, alpha=0.8,
           label=f"{label} — {mask_in.sum():,} corres dans outage")
    ax.set_ylabel("N correspondances / 10s")
    ax.set_title(f"{label}", fontweight='bold')
    ax.legend(fontsize=9)
    ax.grid(axis='y', alpha=0.3)

axes[-1].set_xlabel("GPS time (SOW, s)")
fig.suptitle("Densité des correspondances dans l'outage (tranches 10s)",
             fontsize=12)
fig.tight_layout()
plt.show()

# %%
# Histogramme du Δt entre time_a et time_b pour chaque correspondance

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=False)

for ax, (label, df) in zip(axes, dfs.items()):
    color = '#e74c3c' if 'Run 1' in label else '#27ae60'
    
    dt = (df.time_b - df.time_a).abs()
    mask_in = (df.time_a >= T_OUTAGE_START) & (df.time_a <= T_OUTAGE_END)
    
    dt_in  = dt[mask_in]
    dt_out = dt[~mask_in]
    
    bins = np.logspace(np.log10(dt[dt>0].min()), np.log10(dt.max()), 80)
    
    ax.hist(dt_out, bins=bins, color='#e74c3c', alpha=0.6, label=f'hors outage (N={(~mask_in).sum():,})')
    ax.hist(dt_in,  bins=bins, color=color,     alpha=0.7, label=f'dans outage (N={mask_in.sum():,})')
    
    ax.axvline(dt_in.median(), color='black', lw=1.5, ls='--',
               label=f'médiane={dt_in.median():.2f} s')
    ax.axvline(dt_in.quantile(0.95), color='gray', lw=1.2, ls=':',
               label=f'Q95={dt_in.quantile(0.95):.2f} s')
    
    ax.set_xscale('log')
    ax.set_xlabel('|Δt| = |time_b - time_a| (s)', fontsize=10)
    ax.set_ylabel('N correspondances', fontsize=10)
    ax.set_title(f'{label}', fontsize=11, fontweight='bold')
    ax.legend(fontsize=8)
    ax.grid(axis='y', alpha=0.3)
    
    print(f"{label} — Δt dans outage :")
    print(f"  médiane={dt_in.median():.3f} s  "
          f"Q25={dt_in.quantile(0.25):.3f} s  "
          f"Q75={dt_in.quantile(0.75):.3f} s  "
          f"Q95={dt_in.quantile(0.95):.3f} s  "
          f"max={dt_in.max():.3f} s")
    print()

fig.suptitle('Distribution du |Δt| entre paires de correspondances', fontsize=12)
fig.tight_layout()
plt.show()
# Out:
# Run 1 — Δt dans outage :
#   médiane=1.193 s  Q25=0.980 s  Q75=1.443 s  Q95=2.278 s  max=7.550 s
#
# Run 2 — Δt dans outage :
#   médiane=1.187 s  Q25=0.884 s  Q75=1.604 s  Q95=2.878 s  max=10.101 s

# %%
# Décompose les correspondances par régime de Δt
# et montre la distribution temporelle de chaque régime

REGIMES = [
    ('S2S court',   0,     0.1),    # même scan ou quasi
    ('S2S ~1s',     0.1,   3.0),    # scan consécutifs typiques
    ('F2B court',   3.0,   30.0),   # crossings proches
    ('F2B long',    30.0,  np.inf), # crossings lointains
]

fig, axes = plt.subplots(len(REGIMES), 2, figsize=(15, 3.5*len(REGIMES)),
                         sharex='col', sharey=False)

for ri, (regime_label, dt_lo, dt_hi) in enumerate(REGIMES):
    for ci, (label, df) in enumerate(dfs.items()):
        ax = axes[ri, ci]
        color = '#e74c3c' if 'Run 1' in label else '#27ae60'

        dt   = (df.time_b - df.time_a).abs()
        mask_regime = (dt >= dt_lo) & (dt < dt_hi)
        mask_in     = (df.time_a >= T_OUTAGE_START) & (df.time_a <= T_OUTAGE_END)
        mask        = mask_regime & mask_in

        n = mask.sum()
        if n > 0:
            ax.hist(df.time_a[mask], bins=50, color=color, alpha=0.8)
            ax.axvline(T_OUTAGE_START, color='black', lw=1, ls='--')
            ax.axvline(T_OUTAGE_END,   color='black', lw=1, ls='--')

        ax.set_title(f"{label} — {regime_label}  "
                     f"Δt∈[{dt_lo:.1f}, {dt_hi if dt_hi!=np.inf else '∞'}s]  "
                     f"N={n:,}", fontsize=9, fontweight='bold')
        ax.set_ylabel("N corres")
        if ri == len(REGIMES)-1:
            ax.set_xlabel("time_a (SOW, s)")

        if ri == 0:
            print(f"{label} — {regime_label} : {n:,} corres dans outage "
                  f"({100*n/len(df[mask_in]):.1f}% du total outage)")

    print()

fig.suptitle("Distribution temporelle par régime de Δt", fontsize=12)
fig.tight_layout()
plt.show()
# Out:
# Run 1 — S2S court : 82 corres dans outage (0.2% du total outage)
# Run 2 — S2S court : 406 corres dans outage (1.1% du total outage)

# %%
import pandas as pd
from pathlib import Path

P2P_PATH = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/in/LiDAR_p2p.txt")

df = pd.read_csv(P2P_PATH, header=None)
df_sorted = df.sort_values(0).reset_index(drop=True)

out_path = P2P_PATH.parent / (P2P_PATH.stem + "_sorted.txt")
df_sorted.to_csv(out_path, header=False, index=False, float_format='%.9f')
print(f"{len(df_sorted):,} lignes → {out_path}")
# Out:
# 39,899 lignes → /media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/in/LiDAR_p2p_sorted.txt

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# ── Fichiers source ───────────────────────────────────────────
P2P_BEST  = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/in/LiDAR_p2p.txt")   # Run 1 — base
P2P_OTHER = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/v3_in/LiDAR_p2p.txt")   # Run 2 — complément
P2P_OUT   = Path("/media/b085164/Elements/CALIB_26_02_25/ODyN_calib/APX/outage_2/F2B/v4_in/LiDAR_p2p.txt")

COLS = ['time_a', 'time_b', 'dx_a', 'dy_a', 'dz_a', 'dx_b', 'dy_b', 'dz_b']

df_best  = pd.read_csv(P2P_BEST,  header=None, names=COLS)
df_other = pd.read_csv(P2P_OTHER, header=None, names=COLS)

# ── Zones à compléter depuis Run 2 ───────────────────────────
FILL_ZONES = [
    (305700.0, 305840.0),
    (305980.0, 306050.0),
]

# ── Extraction des zones manquantes depuis Run 2 ──────────────
fill_parts = []
for t0, t1 in FILL_ZONES:
    mask = (df_other.time_a >= t0) & (df_other.time_a <= t1)
    n = mask.sum()
    print(f"  [{t0:.0f}, {t1:.0f}]  → {n:,} corres depuis Run 2")
    fill_parts.append(df_other[mask])

# ── Merge et tri ──────────────────────────────────────────────
df_mixed = pd.concat([df_best] + fill_parts, ignore_index=True)
df_mixed = df_mixed.sort_values('time_a').reset_index(drop=True)

df_mixed.to_csv(P2P_OUT, header=False, index=False, float_format='%.9f')

print(f"\nRun 1  : {len(df_best):,} corres")
print(f"Ajouté : {sum(len(f) for f in fill_parts):,} corres")
print(f"Total  : {len(df_mixed):,} corres → {P2P_OUT.name}")
# Out:
#   [305700, 305840]  → 3,587 corres depuis Run 2
#   [305980, 306050]  → 3,564 corres depuis Run 2
#
# Run 1  : 39,899 corres
# Ajouté : 7,151 corres
# Total  : 47,050 corres → LiDAR_p2p.txt

# %%
# Correspondances communes aux deux fichiers
# Une correspondance est "commune" si (time_a, time_b) est identique dans les deux

common = pd.merge(
    df_best[['time_a', 'time_b']],
    df_other[['time_a', 'time_b']],
    on=['time_a', 'time_b'],
    how='inner'
)

print(f"Run 1  : {len(df_best):,} corres")
print(f"Run 2  : {len(df_other):,} corres")
print(f"Communes (time_a + time_b identiques) : {len(common):,}")
print(f"  → {100*len(common)/len(df_best):.1f}% de Run 1")
print(f"  → {100*len(common)/len(df_other):.1f}% de Run 2")
# Out:
# Run 1  : 39,899 corres
# Run 2  : 62,233 corres
# Communes (time_a + time_b identiques) : 1,196
#   → 3.0% de Run 1
#   → 1.9% de Run 2
